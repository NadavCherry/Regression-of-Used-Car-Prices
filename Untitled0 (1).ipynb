# %%
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
from sklearn.model_selection import train_test_split
import gdown
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import os
import datetime
current_year = datetime.datetime.now().year

# %%
# Path to the zip file
zip_path = r'C:\Users\nadav\PycharmProjects\Regression of Used Car Prices\playground-series-s4e9.zip'

# Open the zip file and read the CSV files directly without extracting
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List the files in the zip to verify
    print(zip_ref.namelist())  # Optional: to list all files in the zip
    
    # Read train.csv and test.csv directly from the zip
    with zip_ref.open('train.csv') as train_file:
        train_data = pd.read_csv(train_file)
    
    with zip_ref.open('test.csv') as test_file:
        test_data = pd.read_csv(test_file)

# Display the first few rows of the train dataset
print(train_data.head())
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  object
#  2   model         125690 non-null  object
#  3   model_year    125690 non-null  int64
#  4   milage        125690 non-null  int64
#  5   fuel_type     122307 non-null  object
#  6   engine        125690 non-null  object
#  7   transmission  125690 non-null  object
#  8   ext_col       125690 non-null  object
#  9   int_col       125690 non-null  object
#  10  accident      124058 non-null  object
#  11  clean_title   111451 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 11.5+ MB

# %%
train_data
# Out:
#             id          brand                     model  model_year  milage  \
# 0            0           MINI             Cooper S Base        2007  213000
# 1            1        Lincoln                     LS V8        2002  143250
# 2            2      Chevrolet         Silverado 2500 LT        2002  136731
# 3            3        Genesis          G90 5.0 Ultimate        2017   19500
# 4            4  Mercedes-Benz               Metris Base        2021    7388
# ...        ...            ...                       ...         ...     ...
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188531  188531           Audi          S5 3.0T Prestige        2022   13895
# 188532  188532        Porsche                Macan Base        2016   59500
#
#             fuel_type                                             engine  \
# 0            Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1            Gasoline       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2       E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3            Gasoline       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4            Gasoline       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...               ...                                                ...
# 188528       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529       Gasoline      385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530       Gasoline       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188531       Gasoline                                               3.0L
# 188532       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                           transmission                    ext_col int_col  \
# 0                                  A/T                     Yellow    Gray
# 1                                  A/T                     Silver   Beige
# 2                                  A/T                       Blue    Gray
# 3       Transmission w/Dual Shift Mode                      Black   Black
# 4                          7-Speed A/T                      Black   Beige
# ...                                ...                        ...     ...
# 188528  Transmission w/Dual Shift Mode                      White   Beige
# 188529                     8-Speed A/T                      White   Black
# 188530                     7-Speed A/T                      White   Black
# 188531               1-Speed Automatic  Daytona Gray Pearl Effect   Black
# 188532  Transmission w/Dual Shift Mode                      White   Black
#
#                                       accident clean_title  price
# 0                                None reported         Yes   4200
# 1       At least 1 accident or damage reported         Yes   4999
# 2                                None reported         Yes  13900
# 3                                None reported         Yes  45000
# 4                                None reported         Yes  97500
# ...                                        ...         ...    ...
# 188528                           None reported         Yes  27500
# 188529  At least 1 accident or damage reported         Yes  30000
# 188530                           None reported         Yes  86900
# 188531                           None reported         NaN  84900
# 188532                           None reported         Yes  28995
#
# [188533 rows x 13 columns]

# %%
missing_values = train_data.select_dtypes(include=['object', 'int64']).isnull().sum()
print(missing_values)
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df = train_data.copy(deep=True)

# %% [markdown]
# make clean_title 0 for all missing value and 1 for 'yes'

# %%
df['clean_title'] = df['clean_title'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
test_data['clean_title'] = test_data['clean_title'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
print(df['clean_title'].value_counts())
# Out:
# clean_title
# 1    167114
# 0     21419
# Name: count, dtype: int64

# %%
df
# Out:
#             id          brand                     model  model_year  milage  \
# 0            0           MINI             Cooper S Base        2007  213000
# 1            1        Lincoln                     LS V8        2002  143250
# 2            2      Chevrolet         Silverado 2500 LT        2002  136731
# 3            3        Genesis          G90 5.0 Ultimate        2017   19500
# 4            4  Mercedes-Benz               Metris Base        2021    7388
# ...        ...            ...                       ...         ...     ...
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188531  188531           Audi          S5 3.0T Prestige        2022   13895
# 188532  188532        Porsche                Macan Base        2016   59500
#
#             fuel_type                                             engine  \
# 0            Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1            Gasoline       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2       E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3            Gasoline       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4            Gasoline       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...               ...                                                ...
# 188528       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529       Gasoline      385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530       Gasoline       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188531       Gasoline                                               3.0L
# 188532       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                           transmission                    ext_col int_col  \
# 0                                  A/T                     Yellow    Gray
# 1                                  A/T                     Silver   Beige
# 2                                  A/T                       Blue    Gray
# 3       Transmission w/Dual Shift Mode                      Black   Black
# 4                          7-Speed A/T                      Black   Beige
# ...                                ...                        ...     ...
# 188528  Transmission w/Dual Shift Mode                      White   Beige
# 188529                     8-Speed A/T                      White   Black
# 188530                     7-Speed A/T                      White   Black
# 188531               1-Speed Automatic  Daytona Gray Pearl Effect   Black
# 188532  Transmission w/Dual Shift Mode                      White   Black
#
#                                       accident  clean_title  price
# 0                                None reported            1   4200
# 1       At least 1 accident or damage reported            1   4999
# 2                                None reported            1  13900
# 3                                None reported            1  45000
# 4                                None reported            1  97500
# ...                                        ...          ...    ...
# 188528                           None reported            1  27500
# 188529  At least 1 accident or damage reported            1  30000
# 188530                           None reported            1  86900
# 188531                           None reported            0  84900
# 188532                           None reported            1  28995
#
# [188533 rows x 13 columns]

# %% [markdown]
# Split the dataset into train and validation sets

# %%
df_train_data, df_val_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black
# 173831                                A/T       Silver    Gray
# 183819                       10-Speed A/T         Gray    Gray
# 85525                         6-Speed M/T        Black   Black
# 41872                         6-Speed A/T          Red   Black
# ...                                   ...          ...     ...
# 119879                        6-Speed M/T          Red   Beige
# 103694                        7-Speed A/T        Black   Black
# 131932                        8-Speed A/T        Black   Black
# 146867                        7-Speed A/T        Black   Black
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black
#
#                                       accident  clean_title   price
# 184031  At least 1 accident or damage reported            1   24000
# 173831  At least 1 accident or damage reported            1    8250
# 183819  At least 1 accident or damage reported            1   30000
# 85525                            None reported            0   45999
# 41872                            None reported            1   42000
# ...                                        ...          ...     ...
# 119879  At least 1 accident or damage reported            1   10000
# 103694                           None reported            1   35900
# 131932                           None reported            1   99750
# 146867                           None reported            1    6730
# 121958                           None reported            0  179900
#
# [150826 rows x 13 columns]

# %%
# Apply logarithmic transformation to the price column
df_train_data['log_price'] = np.log1p(df_train_data['price'])  # log1p is used to avoid log(0)
df_val_data['log_price'] = np.log1p(df_val_data['price'])

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black
# 173831                                A/T       Silver    Gray
# 183819                       10-Speed A/T         Gray    Gray
# 85525                         6-Speed M/T        Black   Black
# 41872                         6-Speed A/T          Red   Black
# ...                                   ...          ...     ...
# 119879                        6-Speed M/T          Red   Beige
# 103694                        7-Speed A/T        Black   Black
# 131932                        8-Speed A/T        Black   Black
# 146867                        7-Speed A/T        Black   Black
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black
#
#                                       accident  clean_title   price  log_price
# 184031  At least 1 accident or damage reported            1   24000  10.085851
# 173831  At least 1 accident or damage reported            1    8250   9.018090
# 183819  At least 1 accident or damage reported            1   30000  10.308986
# 85525                            None reported            0   45999  10.736397
# 41872                            None reported            1   42000  10.645449
# ...                                        ...          ...     ...        ...
# 119879  At least 1 accident or damage reported            1   10000   9.210440
# 103694                           None reported            1   35900  10.488520
# 131932                           None reported            1   99750  11.510432
# 146867                           None reported            1    6730   8.814479
# 121958                           None reported            0  179900  12.100162
#
# [150826 rows x 14 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col       accident  clean_title  \
# 111355  Sunset Drift Chromaflair  Graphite  None reported            0
# 182258                      Gold     Beige            NaN            0
# 14147                  Dark Moss  Chestnut  None reported            1
# 79313                      White     Black            NaN            0
# 101160                      Gray     Black  None reported            1
# ...                          ...       ...            ...          ...
# 71604                       Gray   Ceramic  None reported            1
# 137137                     White     Black  None reported            1
# 70567                        Red      Gray  None reported            1
# 94567                      White     Beige  None reported            1
# 105952                      Gray     Black  None reported            1
#
#          price  log_price
# 111355   37999  10.545341
# 182258   30000  10.308986
# 14147    26772  10.195149
# 79313    24999  10.126631
# 101160   47995  10.778873
# ...        ...        ...
# 71604    49685  10.813478
# 137137  115000  11.652696
# 70567    22000   9.998843
# 94567     3600   8.188967
# 105952   10500   9.259226
#
# [37707 rows x 14 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col       accident  \
# 0              6-Speed A/T            White   Beige  None reported
# 1              8-Speed A/T           Silver   Black  None reported
# 2       10-Speed Automatic            White   Ebony  None reported
# 3                Automatic  Silician Yellow   Black  None reported
# 4                      A/T             Gray   Black  None reported
# ...                    ...              ...     ...            ...
# 125685         7-Speed A/T            Black   Black  None reported
# 125686           Automatic            White   Black  None reported
# 125687                 A/T            Black   Black  None reported
# 125688                 A/T            Black   Black  None reported
# 125689                 A/T           Silver   Black  None reported
#
#         clean_title
# 0                 1
# 1                 1
# 2                 0
# 3                 0
# 4                 1
# ...             ...
# 125685            1
# 125686            0
# 125687            1
# 125688            1
# 125689            1
#
# [125690 rows x 12 columns]

# %% [markdown]
# Target Encoding

# %%
# 2. Perform Target Encoding on the training set
brand_means = df_train_data.groupby('brand')['log_price'].mean()
brand_means
# Out:
# brand
# Acura             9.960201
# Alfa             10.630175
# Aston            11.045903
# Audi             10.310785
# BMW              10.348815
# Bentley          11.221774
# Bugatti          11.576282
# Buick            10.081074
# Cadillac         10.337863
# Chevrolet        10.270755
# Chrysler          9.661749
# Dodge             9.906697
# FIAT              9.961542
# Ferrari          11.211758
# Ford             10.284189
# GMC              10.281075
# Genesis          10.596964
# Honda             9.687013
# Hummer            9.318438
# Hyundai           9.863576
# INFINITI         10.133860
# Jaguar           10.518145
# Jeep             10.125455
# Karma            10.475544
# Kia              10.234611
# Lamborghini      11.542586
# Land             10.533248
# Lexus            10.104125
# Lincoln          10.035032
# Lotus             9.761532
# Lucid            10.871959
# MINI              9.496684
# Maserati         10.697692
# Maybach          10.657848
# Mazda             9.874475
# McLaren          11.372201
# Mercedes-Benz    10.481131
# Mercury           9.626219
# Mitsubishi        9.331123
# Nissan            9.896334
# Plymouth          9.562685
# Polestar         10.426389
# Pontiac           9.393471
# Porsche          10.724007
# RAM              10.555650
# Rivian           11.139204
# Rolls-Royce      11.415289
# Saab              9.980780
# Saturn            9.455017
# Scion             9.472394
# Subaru            9.772203
# Suzuki           10.148457
# Tesla            10.760017
# Toyota            9.926270
# Volkswagen        9.853753
# Volvo            10.081074
# smart             9.888471
# Name: log_price, dtype: float64

# %%
# 3. Map the target encodings back to both the training and test sets
df_train_data['brand_encoded'] = df_train_data['brand'].map(brand_means)
df_val_data['brand_encoded'] = df_val_data['brand'].map(brand_means)
test_data['brand_encoded'] = test_data['brand'].map(brand_means)

# %%
# Handle NaN values in the validation and test sets by assigning filled values back to the columns
df_val_data['brand_encoded'] = df_val_data['brand_encoded'].fillna(df_train_data['log_price'].mean())
test_data['brand_encoded'] = test_data['brand_encoded'].fillna(df_train_data['log_price'].mean())

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black
# 173831                                A/T       Silver    Gray
# 183819                       10-Speed A/T         Gray    Gray
# 85525                         6-Speed M/T        Black   Black
# 41872                         6-Speed A/T          Red   Black
# ...                                   ...          ...     ...
# 119879                        6-Speed M/T          Red   Beige
# 103694                        7-Speed A/T        Black   Black
# 131932                        8-Speed A/T        Black   Black
# 146867                        7-Speed A/T        Black   Black
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black
#
#                                       accident  clean_title   price  \
# 184031  At least 1 accident or damage reported            1   24000
# 173831  At least 1 accident or damage reported            1    8250
# 183819  At least 1 accident or damage reported            1   30000
# 85525                            None reported            0   45999
# 41872                            None reported            1   42000
# ...                                        ...          ...     ...
# 119879  At least 1 accident or damage reported            1   10000
# 103694                           None reported            1   35900
# 131932                           None reported            1   99750
# 146867                           None reported            1    6730
# 121958                           None reported            0  179900
#
#         log_price  brand_encoded
# 184031  10.085851      10.481131
# 173831   9.018090       9.896334
# 183819  10.308986      10.284189
# 85525   10.736397       9.863576
# 41872   10.645449       9.906697
# ...           ...            ...
# 119879   9.210440      10.270755
# 103694  10.488520      10.348815
# 131932  11.510432      10.724007
# 146867   8.814479      10.481131
# 121958  12.100162      10.697692
#
# [150826 rows x 15 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col       accident  clean_title  \
# 111355  Sunset Drift Chromaflair  Graphite  None reported            0
# 182258                      Gold     Beige            NaN            0
# 14147                  Dark Moss  Chestnut  None reported            1
# 79313                      White     Black            NaN            0
# 101160                      Gray     Black  None reported            1
# ...                          ...       ...            ...          ...
# 71604                       Gray   Ceramic  None reported            1
# 137137                     White     Black  None reported            1
# 70567                        Red      Gray  None reported            1
# 94567                      White     Beige  None reported            1
# 105952                      Gray     Black  None reported            1
#
#          price  log_price  brand_encoded
# 111355   37999  10.545341       9.896334
# 182258   30000  10.308986      10.284189
# 14147    26772  10.195149      10.081074
# 79313    24999  10.126631      10.348815
# 101160   47995  10.778873       9.926270
# ...        ...        ...            ...
# 71604    49685  10.813478      10.284189
# 137137  115000  11.652696      10.533248
# 70567    22000   9.998843       9.960201
# 94567     3600   8.188967       9.472394
# 105952   10500   9.259226      10.284189
#
# [37707 rows x 15 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col       accident  \
# 0              6-Speed A/T            White   Beige  None reported
# 1              8-Speed A/T           Silver   Black  None reported
# 2       10-Speed Automatic            White   Ebony  None reported
# 3                Automatic  Silician Yellow   Black  None reported
# 4                      A/T             Gray   Black  None reported
# ...                    ...              ...     ...            ...
# 125685         7-Speed A/T            Black   Black  None reported
# 125686           Automatic            White   Black  None reported
# 125687                 A/T            Black   Black  None reported
# 125688                 A/T            Black   Black  None reported
# 125689                 A/T           Silver   Black  None reported
#
#         clean_title  brand_encoded
# 0                 1      10.533248
# 1                 1      10.533248
# 2                 0      10.284189
# 3                 0      10.310785
# 4                 1      10.310785
# ...             ...            ...
# 125685            1      10.481131
# 125686            0      10.310785
# 125687            1      10.310785
# 125688            1      10.310785
# 125689            1      10.270755
#
# [125690 rows x 13 columns]

# %% [markdown]
# model

# %%
# Visualize the price distribution in the training data
df_train_data['log_price'].hist(bins=10, figsize=(10,6))
plt.xlabel('log_price')
plt.ylabel('Frequency')
plt.title('Distribution of log_prices in Training Data')
plt.show()

# %%
# Step 1: Group the models by their average price in df_train_data
model_mean_prices_train = df_train_data.groupby('model')['log_price'].mean()

# %%
model_mean_prices_train
# Out:
# model
# 124 Spider Abarth          9.731852
# 128 i                      9.474507
# 135 i                      9.592001
# 135 is                     9.963186
# 1500 Big Horn             10.604428
#                             ...
# i8 Base                   10.780918
# tC Anniversary Edition     9.565917
# tC Base                    9.351919
# tC Release Series 6.0      9.344808
# xB Base                    8.961183
# Name: log_price, Length: 1897, dtype: float64

# %%
binned_model_prices, bin_edges = pd.cut(model_mean_prices_train, bins=10, labels=False, retbins=True)

# %%
df_train_data['model_price_bin'] = df_train_data['model'].map(binned_model_prices)

# %%
# Fill NaN values in 'model_price_bin' and assign a special bin (e.g., -1) for missing values
df_train_data['model_price_bin'] = df_train_data['model_price_bin'].fillna(-1)

# %%
# Map the same binned model prices to the validation and test data
model_mean_prices_val = df_val_data['model'].map(model_mean_prices_train)
df_val_data['model_price_bin'] = pd.cut(model_mean_prices_val, bins=bin_edges, labels=False, include_lowest=True)

model_mean_prices_test = test_data['model'].map(model_mean_prices_train)
test_data['model_price_bin'] = pd.cut(model_mean_prices_test, bins=bin_edges, labels=False, include_lowest=True)

# Handle NaN values in validation and test sets by reassigning the result back to the column
df_val_data['model_price_bin'] = df_val_data['model_price_bin'].fillna(-1)
test_data['model_price_bin'] = test_data['model_price_bin'].fillna(-1)

# %%
# After applying pd.cut, cast the 'model_price_bin' to integers
df_train_data['model_price_bin'] = df_train_data['model_price_bin'].astype(int)

# Repeat the same for validation and test data
df_val_data['model_price_bin'] = df_val_data['model_price_bin'].astype(int)
test_data['model_price_bin'] = test_data['model_price_bin'].astype(int)

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black
# 173831                                A/T       Silver    Gray
# 183819                       10-Speed A/T         Gray    Gray
# 85525                         6-Speed M/T        Black   Black
# 41872                         6-Speed A/T          Red   Black
# ...                                   ...          ...     ...
# 119879                        6-Speed M/T          Red   Beige
# 103694                        7-Speed A/T        Black   Black
# 131932                        8-Speed A/T        Black   Black
# 146867                        7-Speed A/T        Black   Black
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black
#
#                                       accident  clean_title   price  \
# 184031  At least 1 accident or damage reported            1   24000
# 173831  At least 1 accident or damage reported            1    8250
# 183819  At least 1 accident or damage reported            1   30000
# 85525                            None reported            0   45999
# 41872                            None reported            1   42000
# ...                                        ...          ...     ...
# 119879  At least 1 accident or damage reported            1   10000
# 103694                           None reported            1   35900
# 131932                           None reported            1   99750
# 146867                           None reported            1    6730
# 121958                           None reported            0  179900
#
#         log_price  brand_encoded  model_price_bin
# 184031  10.085851      10.481131                3
# 173831   9.018090       9.896334                2
# 183819  10.308986      10.284189                5
# 85525   10.736397       9.863576                5
# 41872   10.645449       9.906697                6
# ...           ...            ...              ...
# 119879   9.210440      10.270755                3
# 103694  10.488520      10.348815                4
# 131932  11.510432      10.724007                6
# 146867   8.814479      10.481131                3
# 121958  12.100162      10.697692                8
#
# [150826 rows x 16 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col       accident  clean_title  \
# 111355  Sunset Drift Chromaflair  Graphite  None reported            0
# 182258                      Gold     Beige            NaN            0
# 14147                  Dark Moss  Chestnut  None reported            1
# 79313                      White     Black            NaN            0
# 101160                      Gray     Black  None reported            1
# ...                          ...       ...            ...          ...
# 71604                       Gray   Ceramic  None reported            1
# 137137                     White     Black  None reported            1
# 70567                        Red      Gray  None reported            1
# 94567                      White     Beige  None reported            1
# 105952                      Gray     Black  None reported            1
#
#          price  log_price  brand_encoded  model_price_bin
# 111355   37999  10.545341       9.896334                4
# 182258   30000  10.308986      10.284189                2
# 14147    26772  10.195149      10.081074                5
# 79313    24999  10.126631      10.348815                4
# 101160   47995  10.778873       9.926270                3
# ...        ...        ...            ...              ...
# 71604    49685  10.813478      10.284189                5
# 137137  115000  11.652696      10.533248                6
# 70567    22000   9.998843       9.960201                2
# 94567     3600   8.188967       9.472394                2
# 105952   10500   9.259226      10.284189                2
#
# [37707 rows x 16 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col       accident  \
# 0              6-Speed A/T            White   Beige  None reported
# 1              8-Speed A/T           Silver   Black  None reported
# 2       10-Speed Automatic            White   Ebony  None reported
# 3                Automatic  Silician Yellow   Black  None reported
# 4                      A/T             Gray   Black  None reported
# ...                    ...              ...     ...            ...
# 125685         7-Speed A/T            Black   Black  None reported
# 125686           Automatic            White   Black  None reported
# 125687                 A/T            Black   Black  None reported
# 125688                 A/T            Black   Black  None reported
# 125689                 A/T           Silver   Black  None reported
#
#         clean_title  brand_encoded  model_price_bin
# 0                 1      10.533248                2
# 1                 1      10.533248                6
# 2                 0      10.284189                5
# 3                 0      10.310785                4
# 4                 1      10.310785                3
# ...             ...            ...              ...
# 125685            1      10.481131                3
# 125686            0      10.310785                5
# 125687            1      10.310785                4
# 125688            1      10.310785                4
# 125689            1      10.270755                4
#
# [125690 rows x 14 columns]

# %%
# Calculate the age of the car
df_train_data['car_age'] = current_year - df_train_data['model_year']
df_val_data['car_age'] = current_year - df_val_data['model_year']
test_data['car_age'] = current_year - test_data['model_year']

# %%
# Log-transformed mileage (to reduce skewness)
df_train_data['log_milage'] = np.log1p(df_train_data['milage'])
df_val_data['log_milage'] = np.log1p(df_val_data['milage'])
test_data['log_milage'] = np.log1p(test_data['milage'])

# Scaled mileage (between 0-1 for linear models or neural networks)
scaler = MinMaxScaler()
df_train_data['milage_scaled'] = scaler.fit_transform(df_train_data[['milage']])
df_val_data['milage_scaled'] = scaler.transform(df_val_data[['milage']])
test_data['milage_scaled'] = scaler.transform(test_data[['milage']])

# Scale car_age between 0-1 (Min-Max Scaling)
scaler = MinMaxScaler()
df_train_data['car_age_scaled'] = scaler.fit_transform(df_train_data[['car_age']])
df_val_data['car_age_scaled'] = scaler.transform(df_val_data[['car_age']])
test_data['car_age_scaled'] = scaler.transform(test_data[['car_age']])

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black
# 173831                                A/T       Silver    Gray
# 183819                       10-Speed A/T         Gray    Gray
# 85525                         6-Speed M/T        Black   Black
# 41872                         6-Speed A/T          Red   Black
# ...                                   ...          ...     ...
# 119879                        6-Speed M/T          Red   Beige
# 103694                        7-Speed A/T        Black   Black
# 131932                        8-Speed A/T        Black   Black
# 146867                        7-Speed A/T        Black   Black
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black
#
#                                       accident  clean_title   price  \
# 184031  At least 1 accident or damage reported            1   24000
# 173831  At least 1 accident or damage reported            1    8250
# 183819  At least 1 accident or damage reported            1   30000
# 85525                            None reported            0   45999
# 41872                            None reported            1   42000
# ...                                        ...          ...     ...
# 119879  At least 1 accident or damage reported            1   10000
# 103694                           None reported            1   35900
# 131932                           None reported            1   99750
# 146867                           None reported            1    6730
# 121958                           None reported            0  179900
#
#         log_price  brand_encoded  model_price_bin  car_age  log_milage  \
# 184031  10.085851      10.481131                3        7   11.029650
# 173831   9.018090       9.896334                2       21   12.128117
# 183819  10.308986      10.284189                5        4   11.429555
# 85525   10.736397       9.863576                5        1    8.609590
# 41872   10.645449       9.906697                6        1    8.517393
# ...           ...            ...              ...      ...         ...
# 119879   9.210440      10.270755                3       17   11.397593
# 103694  10.488520      10.348815                4        5   10.956073
# 131932  11.510432      10.724007                6        3   10.357775
# 146867   8.814479      10.481131                3       13   12.133507
# 121958  12.100162      10.697692                8        1    8.697847
#
#         milage_scaled  car_age_scaled
# 184031       0.152075            0.14
# 173831       0.456656            0.42
# 183819       0.226970            0.08
# 85525        0.013295            0.02
# 41872        0.012102            0.02
# ...               ...             ...
# 119879       0.219822            0.34
# 103694       0.141269            0.10
# 131932       0.077550            0.06
# 146867       0.459126            0.26
# 121958       0.014544            0.02
#
# [150826 rows x 20 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col       accident  clean_title  \
# 111355  Sunset Drift Chromaflair  Graphite  None reported            0
# 182258                      Gold     Beige            NaN            0
# 14147                  Dark Moss  Chestnut  None reported            1
# 79313                      White     Black            NaN            0
# 101160                      Gray     Black  None reported            1
# ...                          ...       ...            ...          ...
# 71604                       Gray   Ceramic  None reported            1
# 137137                     White     Black  None reported            1
# 70567                        Red      Gray  None reported            1
# 94567                      White     Beige  None reported            1
# 105952                      Gray     Black  None reported            1
#
#          price  log_price  brand_encoded  model_price_bin  car_age  \
# 111355   37999  10.545341       9.896334                4        2
# 182258   30000  10.308986      10.284189                2       20
# 14147    26772  10.195149      10.081074                5        5
# 79313    24999  10.126631      10.348815                4        8
# 101160   47995  10.778873       9.926270                3        4
# ...        ...        ...            ...              ...      ...
# 71604    49685  10.813478      10.284189                5        3
# 137137  115000  11.652696      10.533248                6        1
# 70567    22000   9.998843       9.960201                2       11
# 94567     3600   8.188967       9.472394                2       11
# 105952   10500   9.259226      10.284189                2       23
#
#         log_milage  milage_scaled  car_age_scaled
# 111355   10.072302       0.058229            0.04
# 182258   10.819798       0.123240            0.40
# 14147    11.605021       0.270551            0.10
# 79313    11.532738       0.251667            0.16
# 101160   11.227268       0.185357            0.08
# ...            ...            ...             ...
# 71604    11.177970       0.176429            0.06
# 137137    7.660114       0.004991            0.02
# 70567    11.193271       0.179153            0.22
# 94567    11.652696       0.283774            0.22
# 105952    8.764210       0.015559            0.46
#
# [37707 rows x 20 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col       accident  \
# 0              6-Speed A/T            White   Beige  None reported
# 1              8-Speed A/T           Silver   Black  None reported
# 2       10-Speed Automatic            White   Ebony  None reported
# 3                Automatic  Silician Yellow   Black  None reported
# 4                      A/T             Gray   Black  None reported
# ...                    ...              ...     ...            ...
# 125685         7-Speed A/T            Black   Black  None reported
# 125686           Automatic            White   Black  None reported
# 125687                 A/T            Black   Black  None reported
# 125688                 A/T            Black   Black  None reported
# 125689                 A/T           Silver   Black  None reported
#
#         clean_title  brand_encoded  model_price_bin  car_age  log_milage  \
# 0                 1      10.533248                2        9   11.492733
# 1                 1      10.533248                6        4    9.120744
# 2                 0      10.284189                5        2   10.244307
# 3                 0      10.310785                4        8   11.022866
# 4                 1      10.310785                3        6   10.985310
# ...             ...            ...              ...      ...         ...
# 125685            1      10.481131                3       10   11.330396
# 125686            0      10.310785                5        5   10.286605
# 125687            1      10.310785                4       12   11.259774
# 125688            1      10.310785                4       12   11.626263
# 125689            1      10.270755                4        6   11.110072
#
#         milage_scaled  car_age_scaled
# 0            0.241788            0.18
# 1            0.022331            0.08
# 2            0.069205            0.04
# 3            0.151045            0.16
# 4            0.145468            0.12
# ...               ...             ...
# 125685       0.205520            0.20
# 125686       0.072205            0.10
# 125687       0.191489            0.24
# 125688       0.276365            0.24
# 125689       0.164831            0.12
#
# [125690 rows x 18 columns]

# %% [markdown]
# **engine**

# %%
# Get unique values from the 'engine' column
unique_engines = df_train_data['engine'].unique()

# Print each unique value on a new line
for engine in unique_engines:
    print(engine)
# Out:
# 208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability
# 239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 416.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 330.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 523.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 4.0L V8 32V GDI DOHC Twin Turbo
# 400.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 210.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3.0L H6 24V GDI DOHC Twin Turbo
# 382.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 175.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 455.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3.6L V6 24V MPFI DOHC Flexible Fuel
# 429.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 305.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 435.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 239.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 235.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 263.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 577.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 210.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 505.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 603.0HP 4.0L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 220.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability
# 242.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 302.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 240.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 5.3L V8 16V GDI OHV
# 420.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 453.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 379.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 550.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3.0L V6 24V GDI DOHC Twin Turbo
# 340.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 5.7L V8 16V MPFI OHV
# 429.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 285.0HP 3.6L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 445.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 641.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 301.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 6.6L V8 16V GDI OHV
# 275.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 273.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 2.4L I4 16V GDI DOHC
# 208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 170.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 3.6L V6 24V MPFI DOHC
# 270.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 610.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 280.0HP 3.2L Flat 6 Cylinder Engine Gasoline Fuel
# 354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 3.5L V6 24V PDI DOHC Twin Turbo
# 390.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 6.2L V8 16V GDI OHV
# 355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 271.0HP Electric Motor Electric Fuel System
# 3.6L V6 24V GDI DOHC
# 360.0HP 6.0L 8 Cylinder Engine Flex Fuel Capability
# 295.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability
# 3.5L 24V SOHC I-VTEC V6
# 425.0HP Electric Motor Electric Fuel System
# 1.6L I4 16V GDI DOHC Turbo
# 333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 240.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 211.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 300.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 290.0HP 3.5L V6 Cylinder Engine Flex Fuel Capability
# 2.7L V6 24V PDI DOHC Twin Turbo
# 473.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 270.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 328.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# Electric
# 230.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 424.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 310.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 6.7L V8 32V DDI OHV Turbo Diesel
# 134.0HP 1.8L 4 Cylinder Engine Gas/Electric Hybrid
# 280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 395.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 295.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 445.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 2.0 Liter Turbo
# 284.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 400.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 370.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel
# 420.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 190.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V GDI DOHC Turbo
# 380.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 4.4 Liter Twin Turbo
# 475.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 460.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 2.7L I4 16V GDI DOHC Turbo
# 260.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 455.0HP Electric Motor Electric Fuel System
# 188.0HP 2.0L 4 Cylinder Engine Gas/Electric Hybrid
# 270.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 4.0L V6 24V MPFI DOHC
# 395.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 2.3L I4 16V GDI DOHC Turbo
# 389.0HP 3.4L V6 Cylinder Engine Gasoline Fuel
# 349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 169.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 260.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 3.5 Liter DOHC
# 262.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 300.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 6.7L V12 48V GDI DOHC Twin Turbo
# 280.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 173.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 518.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 146.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 268.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 835.0HP Electric Motor Electric Fuel System
# 160.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 3.5 Liter SOHC
# 321.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 247.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2.5 Liter
# 449.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 3.5L V6 24V PDI DOHC
# 120.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 2.0 Liter TFSI
# 380.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 378.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 200.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 230.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 210.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 5.0L V8 32V GDI DOHC Supercharged
# 305.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 545.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# –
# 255.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3.0 Liter
# 383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 282.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 2.5L I4 16V
# 210.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 350.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 201.0HP 2.5L Flat 6 Cylinder Engine Gasoline Fuel
# 429.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 315.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 503.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 420.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 2.5L I4 16V PDI DOHC
# 390.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 248.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 242.0HP 3.7L 5 Cylinder Engine Gasoline Fuel
# 320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability
# 316.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 315.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 375.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 5.2L V10 40V PDI DOHC
# 300.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 2.4L I4 16V MPFI DOHC
# 603.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 191.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 3.5 Liter
# 365.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 451.0HP 6.3L 8 Cylinder Engine Gasoline Fuel
# 136.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 382.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 315.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 463.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 312.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 261.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 2.9L V6 24V GDI DOHC Twin Turbo
# 306.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 310.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 500.0HP 4.0L Flat 6 Cylinder Engine Gasoline Fuel
# 4.6 Liter
# 416.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 563.0HP 6.6L 12 Cylinder Engine Gasoline Fuel
# 158.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 184.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 5.6L V8 32V GDI DOHC
# 385.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability
# 300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 404.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 147.0HP 2.4L 4 Cylinder Engine Gas/Electric Hybrid
# 400.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3.3L V6 24V GDI DOHC
# 260.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 188.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 4.4L V8 32V GDI DOHC Twin Turbo
# 290.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 280.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 414.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 573.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 386.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 5.0 Liter
# 300.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 320.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 550.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 4.7L 8 Cylinder Engine Gasoline Fuel
# 440.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 300.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 355.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 215.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 2.5L I4 16V PDI DOHC Turbo
# 3.6 Liter
# 270.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# Dual Motor - Standard
# 260.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 335.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 266.0HP Electric Motor Electric Fuel System
# 201.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 310.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 2.0 Liter
# 220.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 333.0HP 3.2L Straight 6 Cylinder Engine Gasoline Fuel
# 217.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 6.7L I6 24V DDI OHV Turbo Diesel
# 563.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 291.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 425.0HP 6.1L 8 Cylinder Engine Gasoline Fuel
# 182.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 471.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 292.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 350.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel
# 412.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 525.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V PDI DOHC Turbo
# 265.0HP 2.9L Flat 6 Cylinder Engine Gasoline Fuel
# 220.0HP 3.5L 5 Cylinder Engine Gasoline Fuel
# 323.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 293.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 132.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 335.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 591.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 237.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 265.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 443.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 650.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 325.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 6.4L V8 16V MPFI OHV
# 4.0 Liter Twin Turbo
# 560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 518.0HP Electric Motor Electric Fuel System
# 156.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 285.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 395.0HP 5.7L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 409.0HP 3.4L V6 Cylinder Engine Gasoline Fuel
# 200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 510.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 201.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 552.0HP 6.0L 12 Cylinder Engine Flex Fuel Capability
# 600.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 6.0L 8 Cylinder Engine Gasoline Fuel
# 275.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 199.0HP 2.4L 4 Cylinder Engine Gas/Electric Hybrid
# 173.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 201.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 265.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 630.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 403.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability
# 302.0HP 3.5L V6 Cylinder Engine Flex Fuel Capability
# 401.0HP 6.6L 8 Cylinder Engine Gasoline Fuel
# 5.5 Liter
# 136.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 245.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 335.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 218.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 152.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 316.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 335.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 200.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 430.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 400.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 2.5L I4 16V GDI DOHC Turbo
# 202.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 582.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 475.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 204.0HP 2.5L V6 Cylinder Engine Gasoline Fuel
# 3.8L H6 24V GDI DOHC Twin Turbo
# 286.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 302.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 225.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 670.0HP Electric Motor Electric Fuel System
# 2.0L I4 16V GDI DOHC Turbo Flexible Fuel
# 332.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 155.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 523.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 290.0HP 7.4L 8 Cylinder Engine Gasoline Fuel
# 345.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 6.6L V8 32V DDI OHV Turbo Diesel
# 227.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 510.0HP 5.0L 8 Cylinder Engine Flex Fuel Capability
# 244.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V GDI DOHC Flexible Fuel
# 263.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 227.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 278.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 273.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 759.0HP 6.5L 12 Cylinder Engine Gasoline Fuel
# 260.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 250.0HP 7.3L 8 Cylinder Engine Diesel Fuel
# 3.0 Liter TFSI
# 340.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 400.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 295.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 265.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 258.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 200.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 475.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 208.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 450.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 450.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 300.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V GDI SOHC Turbo
# 280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 236.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 260.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# Electric Motor Electric Fuel System
# 329.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 580.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 380.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 4.0L H6 24V GDI DOHC
# 350.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3.0 Liter Turbo
# 3.0L V6 24V GDI DOHC Turbo
# 225.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 182.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 410.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 306.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 2.5L I4 16V GDI DOHC
# 310.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 235.0HP 3.2L Straight 6 Cylinder Engine Gasoline Fuel
# 228.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 206.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 605.0HP 5.7L 10 Cylinder Engine Gasoline Fuel
# 320.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 150.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 255.0HP 5.4L 8 Cylinder Engine Flex Fuel Capability
# 150.0HP 2.0L 4 Cylinder Engine Diesel Fuel
# 2.0L I4 16V GDI DOHC
# 354.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 160.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability
# 355.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability
# 518.0HP 6.3L 8 Cylinder Engine Gasoline Fuel
# 315.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 172.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 122.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 283.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 480.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 500.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 240.0HP 3.2L Straight 6 Cylinder Engine Gasoline Fuel
# 170.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 240.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 503.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 275.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 572.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 2.5L H4 16V GDI DOHC
# 420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 5.3 Liter
# 220.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 181.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel
# 526.0HP 5.2L 8 Cylinder Engine Gasoline Fuel
# 389.0HP 3.0L Straight 6 Cylinder Engine Plug-In Electric/Gas
# 325.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 426.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 571.0HP 6.2L 12 Cylinder Engine Gasoline Fuel
# 362.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 305.0HP 6.8L 10 Cylinder Engine Gasoline Fuel
# 483.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 3.6 Liter DOHC
# 430.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 350.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 248.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 295.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V MPFI DOHC
# 350.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 300.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 290.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 235.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 381.0HP 5.7L 8 Cylinder Engine Flex Fuel Capability
# 6.0L W12 48V PDI DOHC Twin Turbo
# 296.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 292.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# V6
# 330.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 437.0HP 3.4L V6 Cylinder Engine Gas/Electric Hybrid
# 160.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V GDI DOHC Turbo Hybrid
# 326.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 390.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 237.0HP 2.2L 4 Cylinder Engine Gasoline Fuel
# 335.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 500.0HP 8.3L 10 Cylinder Engine Gasoline Fuel
# 345.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 300.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 460.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 191.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 600.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 3.0L V6 24V GDI DOHC Supercharged
# 382.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 425.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 4.0 Liter
# 300.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 420.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 281.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 562.0HP 3.8L 8 Cylinder Engine Gasoline Fuel
# 240.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 285.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 325.0HP 8.1L 8 Cylinder Engine Gasoline Fuel
# 536.0HP Electric Motor Electric Fuel System
# 5.0L 8 Cylinder
# 256.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 288.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 143.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 355.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 560.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 290.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 5.0L V8 32V PDI DOHC
# 140.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 310.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 275.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 300.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 255.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 161.0HP 2.1L 4 Cylinder Engine Diesel Fuel
# 565.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 181.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 450.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 5.6 Liter
# 158.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 247.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 305.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 200.0HP 2.2L 4 Cylinder Engine Gasoline Fuel
# 195.0HP 4.3L V6 Cylinder Engine Gasoline Fuel
# 192.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 225.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 255.0HP 2.9L Flat 6 Cylinder Engine Gasoline Fuel
# 385.0HP 5.0L 8 Cylinder Engine Flex Fuel Capability
# 473.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 265.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 385.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 104.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 200.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 2.0 Liter DOHC Turbo
# 520.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 552.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 543.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 300.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 485.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 295.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 325.0HP 6.0L 8 Cylinder Engine Diesel Fuel
# 533.0HP Electric Motor Electric Fuel System
# 185.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 480.0HP Electric Motor Electric Fuel System
# 246.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 403.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 1.8 Liter
# 4.7 Liter Twin Turbo
# 567.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 300.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 542.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 480.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 3.5L V6 24V PDI DOHC Twin Turbo Hybrid
# 2.5L 4 Cylinder Engine Gasoline Fuel
# 150.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 260.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 417.0HP Electric Motor Electric Fuel System
# 255.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 170.0HP 0.65L Electric Motor Electric Fuel System
# 256.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 416.0HP 3.0L V6 Cylinder Engine Plug-In Electric/Gas
# 577.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 429.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 414.0HP 4.0L Flat 6 Cylinder Engine Gasoline Fuel
# 285.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 261.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 4.4 Liter DOHC Twin Turbo
# 350.0HP 6.4L 8 Cylinder Engine Diesel Fuel
# 207.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 3.8L V8 32V GDI DOHC Twin Turbo
# 2.5L I4 16V MPFI DOHC
# 320.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 192.0HP 2.0L 4 Cylinder Engine Gas/Electric Hybrid
# 160.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 138.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 360.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 6.5L V12 48V MPFI DOHC
# 407.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 255.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 323.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 272.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3.6 Liter SIDI DOHC
# 325.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 275.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 184.0HP 2.5L Straight 6 Cylinder Engine Gasoline Fuel
# 563.0HP Electric Motor Electric Fuel System
# 187.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 142.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 166.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 670.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V MPFI DOHC Hybrid
# 132.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 170.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 357.0HP 1.5L 3 Cylinder Engine Plug-In Electric/Gas
# 3.4L V6 24V PDI DOHC Twin Turbo
# 305.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 285.0HP 4.3L V6 Cylinder Engine Flex Fuel Capability
# 340.0HP 3.0L V6 Cylinder Engine Flex Fuel Capability
# 150.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 602.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 360.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 245.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 210.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 245.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 440.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 153.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 575.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 202.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# Dual AC Electric Motors
# 190.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 310.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability
# 287.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 147.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 760.0HP 5.2L 8 Cylinder Engine Gasoline Fuel
# 5.7 Liter
# 220.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 139.0HP 1.6L 4 Cylinder Engine Plug-In Electric/Gas
# 344.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 3.8L V6 24V GDI DOHC
# 175.0HP 3.9L V6 Cylinder Engine Gasoline Fuel
# 118.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 617.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 616.0HP Electric Motor Electric Fuel System
# 485.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 362.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 335.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 536.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 3.5L V6 24V PDI DOHC Hybrid
# 180.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 305.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 261.0HP 1.6L 4 Cylinder Engine Plug-In Electric/Gas
# 266.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 179.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 1.2L I3 12V GDI DOHC Turbo
# 329.0HP Electric Motor Electric Fuel System
# 272.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 325.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 2.4L H4 16V GDI DOHC Turbo
# 230.0HP 3.2L Straight 6 Cylinder Engine Gasoline Fuel
# 184.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 402.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 375.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 115.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 4.6L V8 32V MPFI DOHC
# 480.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 505.0HP 7.0L 8 Cylinder Engine Gasoline Fuel
# 430.0HP 7.3L 8 Cylinder Engine Gasoline Fuel
# 311.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 5.2L V10 40V GDI DOHC
# 210.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3.0L I6 24V GDI DOHC Twin Turbo
# 300.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 1.6L I4 16V GDI DOHC Hybrid
# 3.4L H6 24V MPFI DOHC
# 3.9L V8 32V GDI DOHC Twin Turbo
# 317.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 3.5L V6 24V MPFI DOHC
# 276.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 550.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 375.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 235.0HP 4.7L 8 Cylinder Engine Flex Fuel Capability
# 390.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 310.0HP 6.8L 10 Cylinder Engine Gasoline Fuel
# 245.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 2.9 Liter Turbo
# 493.0HP 5.5L 12 Cylinder Engine Gasoline Fuel
# 3.0 Liter DOHC Twin Turbo
# 171.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3.5L V6 24V GDI SOHC
# 260.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 174.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3.0L I6 24V GDI DOHC Turbo
# 440.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 130.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 150.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 369.0HP 1.5L 3 Cylinder Engine Plug-In Electric/Gas
# 395.0HP 5.0L 8 Cylinder Engine Flex Fuel Capability
# 265.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 355.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 140.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 168.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# V8
# 335.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 245.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 6.2L V8 16V GDI OHV Supercharged
# 230.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 3.5L V6 24V GDI DOHC Twin Turbo
# 255.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 211.0HP 2.0L 4 Cylinder Engine Diesel Fuel
# 348.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 444.0HP 2.9L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 138.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 4.4 Liter
# 444.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 500.0HP 5.0L 10 Cylinder Engine Gasoline Fuel
# 360.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 440.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 1.6L I4 16V GDI DOHC
# 550.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 169.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 306.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4.0L
# 602.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 324.0HP 6.0L 8 Cylinder Engine Flex Fuel Capability
# 394.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 451.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 173.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 550.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 189.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1.5L I3 12V GDI DOHC Turbo
# 420.0HP 5.9L 12 Cylinder Engine Gasoline Fuel
# 400.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 420.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 168.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 1.6L I4 16V MPFI DOHC
# 275.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 605.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 315.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability
# 153.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 173.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 170.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 557.0HP Electric Motor Electric Fuel System
# 534.0HP Electric Motor Electric Fuel System
# 188.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 335.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 550.0HP 5.0L 8 Cylinder Engine Flex Fuel Capability
# 405.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 1.5L I4 16V GDI DOHC Turbo
# 174.0HP 2.8L V6 Cylinder Engine Gasoline Fuel
# 366.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 621.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 290.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 3.5L V6 24V GDI DOHC
# 390.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 362.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 302.0HP 2.5L 4 Cylinder Engine Plug-In Electric/Gas
# 330.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 562.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 707.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 193.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 405.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 2.4L I4 16V PDI DOHC Turbo
# 109.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 601.0HP 6.6L 12 Cylinder Engine Gasoline Fuel
# 180.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 212.0HP 2.0L 4 Cylinder Engine Gas/Electric Hybrid
# 277.0HP 3.0L Straight 6 Cylinder Engine Diesel Fuel
# 162.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 192.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 797.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 455.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 540.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 320.0HP Electric Motor Electric Fuel System
# 550.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 346.0HP Electric Motor Electric Fuel System
# 205.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 645.0HP 8.4L 10 Cylinder Engine Gasoline Fuel
# 385.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 275.0HP 4.2L Straight 6 Cylinder Engine Gasoline Fuel
# 232.0HP 1.3L Rotary engine Gasoline Fuel
# 231.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 496.0HP 4.0L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 181.0HP 1.5L 3 Cylinder Engine Gasoline Fuel
# 2.0 Liter DOHC T/C
# 160.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 355.0HP Electric Motor Electric Fuel System
# 3.0 Liter SC ULEV
# 375.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 304.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3.2L V6 24V MPFI DOHC
# 4.0 Liter TFSI
# 3.0L
# 348.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 148.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 201.0HP Electric Motor Electric Fuel System
# 6.2L V8 16V MPFI SOHC Flexible Fuel
# 282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 440.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 310.0HP 5.4L 8 Cylinder Engine Flex Fuel Capability
# 355.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 3.4L V6 24V PDI DOHC Twin Turbo Hybrid
# 360.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 430.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 265.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 624.0HP 6.6L 12 Cylinder Engine Gasoline Fuel
# 240.0HP 3.0L V6 Cylinder Engine Flex Fuel Capability
# 250.0HP 5.9L Straight 6 Cylinder Engine Diesel Fuel
# 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 200.0HP 4.3L V6 Cylinder Engine Gasoline Fuel
# 471.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 2.4 Liter
# 227.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 563.0HP 6.7L 12 Cylinder Engine Gasoline Fuel
# 280.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 540.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 3.0 Liter Twin Turbo
# 456.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 201.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3.0L I6 24V DDI DOHC Turbo Diesel
# 2.0 Liter TSI
# 205.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 181.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 5.7L V8 32V MPFI DOHC
# 308.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 405.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 133.0HP 2.2L 4 Cylinder Engine Gasoline Fuel
# 422.0HP Electric Motor Electric Fuel System
# 250.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 611.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 382.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 270.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 591.0HP 4.0L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 225.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 318.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 5.2L V12 48V GDI DOHC Twin Turbo
# 167.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 2.4L I4 16V MPFI SOHC
# 405.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 245.0HP 5.9L 8 Cylinder Engine Gasoline Fuel
# 180.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 115.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 170.0HP 2.5L Straight 6 Cylinder Engine Gasoline Fuel
# 115.0HP 1.7L 4 Cylinder Engine Gasoline Fuel
# 375.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 169.0HP 2.5L 4 Cylinder Engine Flex Fuel Capability
# 393.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 691.0HP Electric Motor Electric Fuel System
# 271.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 252.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# I4
# 416.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 660.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 467.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 107.0HP Electric Motor Electric Fuel System
# 325.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 245.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 518.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 147.0HP Electric Motor Electric Fuel System
# 260.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 247.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 360.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 161.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 286.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 271.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 380.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 482.0HP Electric Motor Electric Fuel System
# 120.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 159.0HP 2.7L 4 Cylinder Engine Gasoline Fuel
# 308.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 264.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 778.0HP Electric Motor Electric Fuel System
# 151.0HP 1.5L 4 Cylinder Engine Gas/Electric Hybrid
# 1.5L I3 12V PDI DOHC Turbo
# 270.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 640.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 250.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 342.0HP 6.0L 8 Cylinder Engine Flex Fuel Capability
# 224.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 228.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3.5 Liter GTDI
# 206.0HP 2.4L 4 Cylinder Engine Gas/Electric Hybrid
# 470.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 2.0L I4 16V GDI DOHC Hybrid
# 176.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 6.75L 8 Cylinder Engine Gasoline Fuel
# 281.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 715.0HP 5.2L 12 Cylinder Engine Gasoline Fuel
# 330.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 300.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 360.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 3.0 Liter GTDI
# 330.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 355.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 5.4 Liter SC DOHC
# 651.0HP 6.3L 12 Cylinder Engine Gasoline Fuel
# 287.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 165.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 166.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 420.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 283.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 303.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 411.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 190.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 375.0HP Electric Motor Electric Fuel System
# 172.0HP 2.4L 4 Cylinder Engine Gas/Electric Hybrid
# 239.0HP 3.7L 5 Cylinder Engine Gasoline Fuel
# 230.0HP 5.2L 8 Cylinder Engine Gasoline Fuel
# 190.0HP 2.8L Straight 6 Cylinder Engine Gasoline Fuel
# 395.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 192.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 397.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 161.0HP 2.0L 4 Cylinder Engine Diesel Fuel
# 296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 493.0HP 5.0L 10 Cylinder Engine Gasoline Fuel
# 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel
# 362.0HP Electric Motor Electric Fuel System
# 198.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 201.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 390.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 444.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 401.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 305.0HP 3.6L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 3.8L V8 32V MPFI DOHC Twin Turbo
# 4.2L V8 32V GDI DOHC Twin Turbo
# 275.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 186.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 305.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 315.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 430.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 335.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 245.0HP 5.9L Straight 6 Cylinder Engine Diesel Fuel
# 650.0HP 5.8L 8 Cylinder Engine Gasoline Fuel
# 6.6 Liter Twin Turbo
# 174.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 303.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 4.0L V8 32V MPFI DOHC Twin Turbo
# 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability
# 255.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 300.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 400.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 278.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 303.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 454.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 416.0HP Electric Motor Electric Fuel System
# 182.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 253.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 303.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 222.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 325.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 152.0HP 3.0L V6 Cylinder Engine Flex Fuel Capability
# 271.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 226.0HP 1.6L 4 Cylinder Engine Gas/Electric Hybrid
# 317.0HP 5.6L 8 Cylinder Engine Flex Fuel Capability
# 340.0HP 8.1L 8 Cylinder Engine Gasoline Fuel
# 295.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 500.0HP Electric Motor Electric Fuel System
# 260.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 340.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 76.0HP 1.5L 4 Cylinder Engine Gas/Electric Hybrid
# 295.0HP Electric Motor Electric Fuel System
# 219.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 6.8L V12 48V GDI DOHC
# 502.0HP 4.0L Flat 6 Cylinder Engine Gasoline Fuel
# 616.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 469.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 360.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 319.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 291.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 244.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 6.2 Liter
# 154.0HP 2.7L 5 Cylinder Engine Diesel Fuel
# 500.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 556.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 150.0HP 2.7L 4 Cylinder Engine Gasoline Fuel
# 250.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 303.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 6.8L V12 48V GDI DOHC Twin Turbo
# 729.0HP 6.5L 12 Cylinder Engine Gasoline Fuel
# 6.0L V8 16V MPFI OHV Flexible Fuel
# Intercooled Turbo Premium Unleaded I-4 2.0 L/122
# 126.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel
# 301.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 444.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 290.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# Intercooled Turbo Diesel V-8 6.7 L/406
# 2.5L I4 16V PDI DOHC Hybrid
# 3.0L V6 24V PDI DOHC Twin Turbo
# 6.4 Liter
# 180.0HP 1.6L 4 Cylinder Engine Plug-In Electric/Gas
# 405.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 710.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 177.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 638.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 375.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 450.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 510.0HP 5.5L 12 Cylinder Engine Gasoline Fuel
# 4.0 Liter Turbo
# 521.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 3.6L V6 GDI DOHC
# 190.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 2.5L H4 16V MPFI DOHC
# 201.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 203.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 4.2L V8 32V GDI DOHC
# 3.0 Liter DOHC Turbo
# 3.8L H6 24V MPFI DOHC
# 365.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 2.7L V6 24V GDI DOHC Twin Turbo
# 3.6L V6 24V MPFI DOHC Hybrid
# 101.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 1020.0HP Electric Motor Electric Fuel System
# 275.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 210.0HP 5.8L 8 Cylinder Engine Gasoline Fuel
# 5.3L V8 16V MPFI OHV Flexible Fuel
# 180.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 294.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 200.0HP Electric Motor Electric Fuel System
# 363.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 120 AH
# 132.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 5.8L V8 32V MPFI DOHC Supercharged
# 5.4 Liter
# 290.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 197.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 456.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 355.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 12 Cylinder Engine
# 2.5L
# 808.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 180.0HP 3.4L V6 Cylinder Engine Gasoline Fuel
# 440.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 178.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 400.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 6.4L V8 32V DDI OHV Twin Turbo Diesel
# 181.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 173.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 180.0HP 2.4L 4 Cylinder Engine Flex Fuel Capability
# 380.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# Standard Range Battery
# 540.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 140.0HP 2.8L V6 Cylinder Engine Gasoline Fuel
# 2.7 Liter DOHC Turbo
# 212.0HP 1.3L Rotary engine Gasoline Fuel
# 550.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 543.0HP 5.5L 12 Cylinder Engine Gasoline Fuel
# 341.0HP 6.0L 8 Cylinder Engine Flex Fuel Capability
# 353.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 147.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 215.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 270.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 365.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 320.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 214.0HP Electric Motor Electric Fuel System
# 372.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 788.0HP 6.5L 12 Cylinder Engine Gasoline Fuel
# 282.0HP 3.5L V6 Cylinder Engine Flex Fuel Capability
# 197.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 702.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 306.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 121.0HP 1.8L 4 Cylinder Engine Gas/Electric Hybrid
# 181.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 1.3L I3 12V MPFI DOHC Turbo
# 1.3L I3 12V GDI DOHC Turbo
# 221.0HP 2.5L 4 Cylinder Engine Plug-In Electric/Gas
# 156.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 190.0HP 4.3L V6 Cylinder Engine Gasoline Fuel
# 265.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 453.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 70.0HP 1.0L 3 Cylinder Engine Gasoline Fuel
# 326.0HP 5.4L 12 Cylinder Engine Gasoline Fuel
# 8.0L W16 64V GDI DOHC Twin Turbo
# 170.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 402.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3.2L V6 18V MPFI SOHC
# 402.0HP Electric Motor Electric Fuel System
# 3.8L V6 24V MPFI DOHC Twin Turbo
# 281.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3.2L H6 24V MPFI DOHC
# 210.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel
# 444.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 261.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 270.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 310.0HP 2.7L 4 Cylinder Engine Gasoline Fuel
# 2.5L I4 16V MPFI DOHC Hybrid
# 375.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 325.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 205.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 131.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 243.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 290.0HP Electric Motor Electric Fuel System
# 500.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 321.0HP 3.0L V6 Cylinder Engine Gas/Electric Hybrid
# 555.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 266.0HP 2.5L 4 Cylinder Engine Plug-In Electric/Gas
# 215.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 400.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 354.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 385.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel
# 250.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 620.0HP Electric Motor Electric Fuel System
# 212.0HP 4.5L Straight 6 Cylinder Engine Gasoline Fuel
# 272.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 175.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 403.0HP 2.0L Electric Motor Electric Fuel System
# 186.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 260.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 1.6L I4 16V GDI DOHC Turbo Hybrid
# 318.0HP 3.3L V6 Cylinder Engine Gas/Electric Hybrid
# 148.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 240.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 137.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 182.0HP 2.4L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 325.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 308.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 1.5 Liter Turbo
# 276.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 495.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 332.0HP 6.0L 8 Cylinder Engine Gas/Electric Hybrid
# 298.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 215.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 310.0HP 4.7L 8 Cylinder Engine Flex Fuel Capability
# 180.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 106.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 640.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 415.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 260.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 306.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 182.0HP Electric Motor Hydrogen Fuel
# 215.0HP 2.5L Straight 6 Cylinder Engine Gasoline Fuel
# 2.0 Liter Supercharged
# 345.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 6.2L V8 32V MPFI DOHC
# 197.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 156.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 221.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 109.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 155.0HP 1.3L 3 Cylinder Engine Gasoline Fuel
# 450.0HP 4.5L 8 Cylinder Engine Gasoline Fuel
# 321.0HP Electric Motor Electric Fuel System
# 145.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 250.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 295.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 553.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# Battery Electric
# 134.0HP 1.8L 4 Cylinder Engine Plug-In Electric/Gas
# 111.2Ah / FR 70kW / RR 160kW (697V)
# 275.0HP 3.5L V6 Cylinder Engine Flex Fuel Capability
# 1.4L I4 16V GDI DOHC Turbo
# 210.0HP 2.0L 4 Cylinder Engine Diesel Fuel
# 227.0HP 1.6L 4 Cylinder Engine Gas/Electric Hybrid
# 6.3L V12 48V GDI DOHC
# 240.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 369.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 225.0HP 4.6L 8 Cylinder Engine Flex Fuel Capability
# 138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 111.0HP Electric Motor Electric Fuel System
# 180.0HP 6.5L 8 Cylinder Engine Diesel Fuel
# 141.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 115.0HP Electric Motor Electric Fuel System
# 300.0HP 1.6L 3 Cylinder Engine Gasoline Fuel
# 208.0HP 3.3L V6 Cylinder Engine Gas/Electric Hybrid
# 288.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 3.0L V6 Cylinder Engine Diesel Fuel
# 279.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 120.0HP 2.2L 4 Cylinder Engine Flex Fuel Capability
# 151.0HP Electric Motor Hydrogen Fuel
# 250.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 3.8L V6 12V MPFI OHV
# 280.0HP 2.8L V6 Cylinder Engine Gasoline Fuel
# 6.0L V8 16V MPFI OHV
# 567.0HP 6.0L 12 Cylinder Engine Flex Fuel Capability
# 322.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 4.4 Liter GDI DOHC Twin Turbo
# 443.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 212.0HP 1.5L 4 Cylinder Engine Plug-In Electric/Gas
# 184.0HP 2.4L 4 Cylinder Engine Flex Fuel Capability
# 313.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 170.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 78.0HP 1.2L 3 Cylinder Engine Gasoline Fuel
# 139.0HP 1.6L 4 Cylinder Engine Gas/Electric Hybrid

# %%
# Extract horsepower
def extract_horsepower(engine_str):
    match = re.search(r'(\d+\.?\d*)\s*HP', engine_str)
    return float(match.group(1)) if match else None

# Extract engine volume
def extract_engine_volume(engine_str):
    match = re.search(r'(\d+\.\d+)\s*L', engine_str)
    return float(match.group(1)) if match else None

# Extract number of cylinders
def extract_cylinders(engine_str):
    # Cylinders
    cylinders_match = re.search(r'(\d+)\s*Cylinder|V(\d+)|Flat\s*(\d+)|Straight\s*(\d+)', engine_str)
    if cylinders_match:
        if cylinders_match.group(1):  # Case: '4 Cylinder'
            cylinders = int(cylinders_match.group(1))
        elif cylinders_match.group(2):  # Case: 'V6'
            cylinders = int(cylinders_match.group(2))
        elif cylinders_match.group(3):  # Case: 'Flat 6'
            cylinders = int(cylinders_match.group(3))
        elif cylinders_match.group(4):  # Case: 'Straight 6'
            cylinders = int(cylinders_match.group(4))
    else:
        cylinders = None

    return cylinders


# Extract fuel type
def extract_fuel_type(engine_str):
    if 'Gasoline' in engine_str:
        fuel_type = 'Gasoline'
    elif 'Diesel' in engine_str:
        fuel_type = 'Diesel'
    elif 'Electric' in engine_str:
        fuel_type = 'Electric'
    elif 'Plug-In Hybrid' in engine_str:
        fuel_type = 'Plug-In Hybrid'
    elif 'Hybrid' in engine_str:
        fuel_type = 'Hybrid'
    elif 'Flex Fuel' in engine_str:
        fuel_type = 'E85 Flex Fuel'
    elif engine_str == '–':
        fuel_type = 'Unknown'  # Handle missing data case
    elif engine_str == 'not supported':
        fuel_type = 'Unsupported'  # Handle unsupported fuel type case
    else:
        fuel_type = 'Unknown'
    return fuel_type

# Extract engine type (Turbo, TSI, TFSI, etc.)
def extract_engine_type(engine_str):
    engine_type = []

    if 'Turbo' in engine_str:
        engine_type.append('Turbo')
    if 'TSI' in engine_str:
        engine_type.append('TSI')
    if 'TFSI' in engine_str:
        engine_type.append('TFSI')
    if 'Supercharged' in engine_str:
        engine_type.append('Supercharged')
    if 'VTEC' in engine_str:
        engine_type.append('VTEC')
    if 'Twin Turbo' in engine_str:
        engine_type.append('Twin Turbo')

    return ', '.join(engine_type) if engine_type else 'Standard'

# %%
# Apply the functions to the engine column
import re
df_train_data['horsepower'] = df_train_data['engine'].apply(extract_horsepower)
df_train_data['engine_volume'] = df_train_data['engine'].apply(extract_engine_volume)
df_train_data['cylinders'] = df_train_data['engine'].apply(extract_cylinders)
df_train_data['fuel_engine_type'] = df_train_data['engine'].apply(extract_fuel_type)
df_train_data['engine_type'] = df_train_data['engine'].apply(extract_engine_type)

# Apply the extraction functions to df_val_data
df_val_data['horsepower'] = df_val_data['engine'].apply(extract_horsepower)
df_val_data['engine_volume'] = df_val_data['engine'].apply(extract_engine_volume)
df_val_data['cylinders'] = df_val_data['engine'].apply(extract_cylinders)
df_val_data['fuel_engine_type'] = df_val_data['engine'].apply(extract_fuel_type)
df_val_data['engine_type'] = df_val_data['engine'].apply(extract_engine_type)

# Apply the extraction functions to test_data
test_data['horsepower'] = test_data['engine'].apply(extract_horsepower)
test_data['engine_volume'] = test_data['engine'].apply(extract_engine_volume)
test_data['cylinders'] = test_data['engine'].apply(extract_cylinders)
test_data['fuel_engine_type'] = test_data['engine'].apply(extract_fuel_type)
test_data['engine_type'] = test_data['engine'].apply(extract_engine_type)

# %%
df_train_data['fuel_engine_type'].value_counts()
# Out:
# fuel_engine_type
# Gasoline         111862
# Unknown           25200
# Electric           6085
# E85 Flex Fuel      4128
# Diesel             3240
# Hybrid              311
# Name: count, dtype: int64

# %%
df_train_data['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline          132832
# Hybrid              5437
# E85 Flex Fuel       4328
# Diesel              3101
# –                    625
# Plug-In Hybrid       433
# not supported         10
# Name: count, dtype: int64

# %%
train_missing_fuel = df_train_data['fuel_type'].isnull().sum()
train_missing_fuel
# Out:
# np.int64(4060)

# %%
# Update rows where fuel_type is 'nan' or missing, based on fuel_engine_type
def complete_fuel_type(row):
    if pd.isna(row['fuel_type']) or row['fuel_type'] in ['–', 'not supported', 'nan']:
        if row['fuel_engine_type'] != 'Unknown':
            return row['fuel_engine_type']
    return row['fuel_type']

# %%
# Apply this function to each row in the dataframe
df_train_data['fuel_type'] = df_train_data.apply(complete_fuel_type, axis=1)
df_val_data['fuel_type'] = df_val_data.apply(complete_fuel_type, axis=1)
test_data['fuel_type'] = test_data.apply(complete_fuel_type, axis=1)

# %%
df_train_data['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline          132879
# Hybrid              5437
# E85 Flex Fuel       4329
# Electric            3893
# Diesel              3103
# –                    619
# Plug-In Hybrid       433
# Name: count, dtype: int64

# %%
train_missing_fuel = df_train_data['fuel_type'].isnull().sum()
train_missing_fuel
# Out:
# np.int64(133)

# %%
# rows_with_diff_fuel_type = df_train_data[df_train_data['fuel_engine_type'] != df_train_data['fuel_type']]

# # Iterate through each row and print fuel_type and fuel_engine_type
# for index, row in rows_with_diff_fuel_type.iterrows():
#   if row['fuel_engine_type'] == 'Unknown':
#     continue
#   print(f"{row['id']} {row['fuel_type']} {row['fuel_engine_type']}")

# %%
df_train_data.drop(columns=['fuel_engine_type'], inplace=True)
df_val_data.drop(columns=['fuel_engine_type'], inplace=True)
test_data.drop(columns=['fuel_engine_type'], inplace=True)

# %%
df_train_data['engine_type'].value_counts()
# Out:
# engine_type
# Standard             138423
# Turbo                  5902
# Turbo, Twin Turbo      5487
# TFSI                    671
# Supercharged            300
# TSI                      30
# VTEC                     13
# Name: count, dtype: int64

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        brand_encoded  model_price_bin  car_age  log_milage  milage_scaled  \
# 184031     10.481131                3        7   11.029650       0.152075
# 173831      9.896334                2       21   12.128117       0.456656
# 183819     10.284189                5        4   11.429555       0.226970
# 85525       9.863576                5        1    8.609590       0.013295
# 41872       9.906697                6        1    8.517393       0.012102
# ...              ...              ...      ...         ...            ...
# 119879     10.270755                3       17   11.397593       0.219822
# 103694     10.348815                4        5   10.956073       0.141269
# 131932     10.724007                6        3   10.357775       0.077550
# 146867     10.481131                3       13   12.133507       0.459126
# 121958     10.697692                8        1    8.697847       0.014544
#
#         car_age_scaled  horsepower  engine_volume  cylinders  \
# 184031            0.14       208.0            2.0        4.0
# 173831            0.42       239.0            4.0        6.0
# 183819            0.08       325.0            2.7        6.0
# 85525             0.02       276.0            2.0        4.0
# 41872             0.02       717.0            6.2        8.0
# ...                ...         ...            ...        ...
# 119879            0.34       350.0            5.7        8.0
# 103694            0.10       320.0            3.0        6.0
# 131932            0.06       420.0            3.0        6.0
# 146867            0.26       268.0            3.5        6.0
# 121958            0.02         NaN            3.0        6.0
#
#               engine_type
# 184031           Standard
# 173831           Standard
# 183819           Standard
# 85525            Standard
# 41872            Standard
# ...                   ...
# 119879           Standard
# 103694           Standard
# 131932           Standard
# 146867           Standard
# 121958  Turbo, Twin Turbo
#
# [150826 rows x 24 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... brand_encoded  \
# 111355  Sunset Drift Chromaflair  Graphite  ...      9.896334
# 182258                      Gold     Beige  ...     10.284189
# 14147                  Dark Moss  Chestnut  ...     10.081074
# 79313                      White     Black  ...     10.348815
# 101160                      Gray     Black  ...      9.926270
# ...                          ...       ...  ...           ...
# 71604                       Gray   Ceramic  ...     10.284189
# 137137                     White     Black  ...     10.533248
# 70567                        Red      Gray  ...      9.960201
# 94567                      White     Beige  ...      9.472394
# 105952                      Gray     Black  ...     10.284189
#
#         model_price_bin  car_age  log_milage  milage_scaled  car_age_scaled  \
# 111355                4        2   10.072302       0.058229            0.04
# 182258                2       20   10.819798       0.123240            0.40
# 14147                 5        5   11.605021       0.270551            0.10
# 79313                 4        8   11.532738       0.251667            0.16
# 101160                3        4   11.227268       0.185357            0.08
# ...                 ...      ...         ...            ...             ...
# 71604                 5        3   11.177970       0.176429            0.06
# 137137                6        1    7.660114       0.004991            0.02
# 70567                 2       11   11.193271       0.179153            0.22
# 94567                 2       11   11.652696       0.283774            0.22
# 105952                2       23    8.764210       0.015559            0.46
#
#         horsepower  engine_volume  cylinders        engine_type
# 111355         NaN            3.5        6.0           Standard
# 182258       280.0            3.9        8.0           Standard
# 14147          NaN            3.6        6.0           Standard
# 79313        320.0            3.0        6.0           Standard
# 101160       295.0            3.5        6.0           Standard
# ...            ...            ...        ...                ...
# 71604          NaN            3.5        6.0  Turbo, Twin Turbo
# 137137       296.0            2.0        4.0           Standard
# 70567        280.0            3.5        6.0           Standard
# 94567        179.0            2.5        4.0           Standard
# 105952       300.0            4.4        8.0           Standard
#
# [37707 rows x 24 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ... brand_encoded  \
# 0              6-Speed A/T            White   Beige  ...     10.533248
# 1              8-Speed A/T           Silver   Black  ...     10.533248
# 2       10-Speed Automatic            White   Ebony  ...     10.284189
# 3                Automatic  Silician Yellow   Black  ...     10.310785
# 4                      A/T             Gray   Black  ...     10.310785
# ...                    ...              ...     ...  ...           ...
# 125685         7-Speed A/T            Black   Black  ...     10.481131
# 125686           Automatic            White   Black  ...     10.310785
# 125687                 A/T            Black   Black  ...     10.310785
# 125688                 A/T            Black   Black  ...     10.310785
# 125689                 A/T           Silver   Black  ...     10.270755
#
#         model_price_bin  car_age  log_milage  milage_scaled  car_age_scaled  \
# 0                     2        9   11.492733       0.241788            0.18
# 1                     6        4    9.120744       0.022331            0.08
# 2                     5        2   10.244307       0.069205            0.04
# 3                     4        8   11.022866       0.151045            0.16
# 4                     3        6   10.985310       0.145468            0.12
# ...                 ...      ...         ...            ...             ...
# 125685                3       10   11.330396       0.205520            0.20
# 125686                5        5   10.286605       0.072205            0.10
# 125687                4       12   11.259774       0.191489            0.24
# 125688                4       12   11.626263       0.276365            0.24
# 125689                4        6   11.110072       0.164831            0.12
#
#         horsepower  engine_volume  cylinders        engine_type
# 0            240.0            2.0        4.0           Standard
# 1            395.0            3.0        6.0           Standard
# 2              NaN            3.5        6.0  Turbo, Twin Turbo
# 3              NaN            2.0        NaN               TFSI
# 4            252.0            2.0        4.0           Standard
# ...            ...            ...        ...                ...
# 125685       362.0            3.0        6.0           Standard
# 125686         NaN            3.0        NaN              Turbo
# 125687       333.0            3.0        6.0           Standard
# 125688       333.0            3.0        6.0           Standard
# 125689       355.0            5.3        8.0           Standard
#
# [125690 rows x 22 columns]

# %%
# Step 1: Initialize LabelEncoder
le = LabelEncoder()

# Step 2: Fit on the 'engine_type' column of the training data
df_train_data['engine_type_encoded'] = le.fit_transform(df_train_data['engine_type'])

# Step 3: Apply the same transformation to the validation and test sets using the encoder from the training set
df_val_data['engine_type_encoded'] = df_val_data['engine_type'].apply(lambda x: le.transform([x])[0] if x in le.classes_ else -1)
test_data['engine_type_encoded'] = test_data['engine_type'].apply(lambda x: le.transform([x])[0] if x in le.classes_ else -1)

# Now 'engine_type_encoded' columns are ready for model input

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        model_price_bin  car_age  log_milage  milage_scaled  car_age_scaled  \
# 184031               3        7   11.029650       0.152075            0.14
# 173831               2       21   12.128117       0.456656            0.42
# 183819               5        4   11.429555       0.226970            0.08
# 85525                5        1    8.609590       0.013295            0.02
# 41872                6        1    8.517393       0.012102            0.02
# ...                ...      ...         ...            ...             ...
# 119879               3       17   11.397593       0.219822            0.34
# 103694               4        5   10.956073       0.141269            0.10
# 131932               6        3   10.357775       0.077550            0.06
# 146867               3       13   12.133507       0.459126            0.26
# 121958               8        1    8.697847       0.014544            0.02
#
#         horsepower  engine_volume  cylinders        engine_type  \
# 184031       208.0            2.0        4.0           Standard
# 173831       239.0            4.0        6.0           Standard
# 183819       325.0            2.7        6.0           Standard
# 85525        276.0            2.0        4.0           Standard
# 41872        717.0            6.2        8.0           Standard
# ...            ...            ...        ...                ...
# 119879       350.0            5.7        8.0           Standard
# 103694       320.0            3.0        6.0           Standard
# 131932       420.0            3.0        6.0           Standard
# 146867       268.0            3.5        6.0           Standard
# 121958         NaN            3.0        6.0  Turbo, Twin Turbo
#
#         engine_type_encoded
# 184031                    0
# 173831                    0
# 183819                    0
# 85525                     0
# 41872                     0
# ...                     ...
# 119879                    0
# 103694                    0
# 131932                    0
# 146867                    0
# 121958                    5
#
# [150826 rows x 25 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... model_price_bin  car_age  \
# 111355  Sunset Drift Chromaflair  Graphite  ...               4        2
# 182258                      Gold     Beige  ...               2       20
# 14147                  Dark Moss  Chestnut  ...               5        5
# 79313                      White     Black  ...               4        8
# 101160                      Gray     Black  ...               3        4
# ...                          ...       ...  ...             ...      ...
# 71604                       Gray   Ceramic  ...               5        3
# 137137                     White     Black  ...               6        1
# 70567                        Red      Gray  ...               2       11
# 94567                      White     Beige  ...               2       11
# 105952                      Gray     Black  ...               2       23
#
#         log_milage  milage_scaled  car_age_scaled  horsepower  engine_volume  \
# 111355   10.072302       0.058229            0.04         NaN            3.5
# 182258   10.819798       0.123240            0.40       280.0            3.9
# 14147    11.605021       0.270551            0.10         NaN            3.6
# 79313    11.532738       0.251667            0.16       320.0            3.0
# 101160   11.227268       0.185357            0.08       295.0            3.5
# ...            ...            ...             ...         ...            ...
# 71604    11.177970       0.176429            0.06         NaN            3.5
# 137137    7.660114       0.004991            0.02       296.0            2.0
# 70567    11.193271       0.179153            0.22       280.0            3.5
# 94567    11.652696       0.283774            0.22       179.0            2.5
# 105952    8.764210       0.015559            0.46       300.0            4.4
#
#         cylinders        engine_type  engine_type_encoded
# 111355        6.0           Standard                    0
# 182258        8.0           Standard                    0
# 14147         6.0           Standard                    0
# 79313         6.0           Standard                    0
# 101160        6.0           Standard                    0
# ...           ...                ...                  ...
# 71604         6.0  Turbo, Twin Turbo                    5
# 137137        4.0           Standard                    0
# 70567         6.0           Standard                    0
# 94567         4.0           Standard                    0
# 105952        8.0           Standard                    0
#
# [37707 rows x 25 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ... model_price_bin  \
# 0              6-Speed A/T            White   Beige  ...               2
# 1              8-Speed A/T           Silver   Black  ...               6
# 2       10-Speed Automatic            White   Ebony  ...               5
# 3                Automatic  Silician Yellow   Black  ...               4
# 4                      A/T             Gray   Black  ...               3
# ...                    ...              ...     ...  ...             ...
# 125685         7-Speed A/T            Black   Black  ...               3
# 125686           Automatic            White   Black  ...               5
# 125687                 A/T            Black   Black  ...               4
# 125688                 A/T            Black   Black  ...               4
# 125689                 A/T           Silver   Black  ...               4
#
#         car_age  log_milage  milage_scaled  car_age_scaled  horsepower  \
# 0             9   11.492733       0.241788            0.18       240.0
# 1             4    9.120744       0.022331            0.08       395.0
# 2             2   10.244307       0.069205            0.04         NaN
# 3             8   11.022866       0.151045            0.16         NaN
# 4             6   10.985310       0.145468            0.12       252.0
# ...         ...         ...            ...             ...         ...
# 125685       10   11.330396       0.205520            0.20       362.0
# 125686        5   10.286605       0.072205            0.10         NaN
# 125687       12   11.259774       0.191489            0.24       333.0
# 125688       12   11.626263       0.276365            0.24       333.0
# 125689        6   11.110072       0.164831            0.12       355.0
#
#         engine_volume  cylinders        engine_type  engine_type_encoded
# 0                 2.0        4.0           Standard                    0
# 1                 3.0        6.0           Standard                    0
# 2                 3.5        6.0  Turbo, Twin Turbo                    5
# 3                 2.0        NaN               TFSI                    2
# 4                 2.0        4.0           Standard                    0
# ...               ...        ...                ...                  ...
# 125685            3.0        6.0           Standard                    0
# 125686            3.0        NaN              Turbo                    4
# 125687            3.0        6.0           Standard                    0
# 125688            3.0        6.0           Standard                    0
# 125689            5.3        8.0           Standard                    0
#
# [125690 rows x 23 columns]

# %%
df_train_data['engine_type_encoded']
# Out:
# 184031    0
# 173831    0
# 183819    0
# 85525     0
# 41872     0
#          ..
# 119879    0
# 103694    0
# 131932    0
# 146867    0
# 121958    5
# Name: engine_type_encoded, Length: 150826, dtype: int64

# %%
df_train_data.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price', 'log_price', 'brand_encoded', 'model_price_bin', 'car_age',
#        'log_milage', 'milage_scaled', 'car_age_scaled', 'horsepower',
#        'engine_volume', 'cylinders', 'engine_type', 'engine_type_encoded'],
#       dtype='object')

# %%
df_val_data.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price', 'log_price', 'brand_encoded', 'model_price_bin', 'car_age',
#        'log_milage', 'milage_scaled', 'car_age_scaled', 'horsepower',
#        'engine_volume', 'cylinders', 'engine_type', 'engine_type_encoded'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'brand_encoded', 'model_price_bin', 'car_age', 'log_milage',
#        'milage_scaled', 'car_age_scaled', 'horsepower', 'engine_volume',
#        'cylinders', 'engine_type', 'engine_type_encoded'],
#       dtype='object')

# %%
# Step 1: Perform one-hot encoding on the 'engine_type' column in the training data
df_train_data = pd.get_dummies(df_train_data, columns=['engine_type'], prefix='engine_type', drop_first=False)

# Step 2: Extract the one-hot columns generated in the training data
one_hot_columns = [col for col in df_train_data.columns if 'engine_type_' in col]

# Remove 'price' and 'log_price' from the list of columns to reindex on
train_columns = df_train_data.columns.drop(['price', 'log_price'])

# Step 3: Check for duplicate columns in train data and remove them if needed
train_columns = train_columns.drop_duplicates()

# Apply the same one-hot encoding to the validation and test data
df_val_data = pd.get_dummies(df_val_data, columns=['engine_type'], prefix='engine_type', drop_first=False)
df_val_data = df_val_data.reindex(columns=df_train_data.columns, fill_value=0)

test_data = pd.get_dummies(test_data, columns=['engine_type'], prefix='engine_type', drop_first=False)
test_data = test_data.reindex(columns=train_columns, fill_value=0)

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        engine_volume  cylinders  engine_type_encoded  engine_type_Standard  \
# 184031           2.0        4.0                    0                  True
# 173831           4.0        6.0                    0                  True
# 183819           2.7        6.0                    0                  True
# 85525            2.0        4.0                    0                  True
# 41872            6.2        8.0                    0                  True
# ...              ...        ...                  ...                   ...
# 119879           5.7        8.0                    0                  True
# 103694           3.0        6.0                    0                  True
# 131932           3.0        6.0                    0                  True
# 146867           3.5        6.0                    0                  True
# 121958           3.0        6.0                    5                 False
#
#         engine_type_Supercharged  engine_type_TFSI  engine_type_TSI  \
# 184031                     False             False            False
# 173831                     False             False            False
# 183819                     False             False            False
# 85525                      False             False            False
# 41872                      False             False            False
# ...                          ...               ...              ...
# 119879                     False             False            False
# 103694                     False             False            False
# 131932                     False             False            False
# 146867                     False             False            False
# 121958                     False             False            False
#
#         engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC
# 184031              False                          False             False
# 173831              False                          False             False
# 183819              False                          False             False
# 85525               False                          False             False
# 41872               False                          False             False
# ...                   ...                            ...               ...
# 119879              False                          False             False
# 103694              False                          False             False
# 131932              False                          False             False
# 146867              False                          False             False
# 121958              False                           True             False
#
# [150826 rows x 31 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... engine_volume  cylinders  \
# 111355  Sunset Drift Chromaflair  Graphite  ...           3.5        6.0
# 182258                      Gold     Beige  ...           3.9        8.0
# 14147                  Dark Moss  Chestnut  ...           3.6        6.0
# 79313                      White     Black  ...           3.0        6.0
# 101160                      Gray     Black  ...           3.5        6.0
# ...                          ...       ...  ...           ...        ...
# 71604                       Gray   Ceramic  ...           3.5        6.0
# 137137                     White     Black  ...           2.0        4.0
# 70567                        Red      Gray  ...           3.5        6.0
# 94567                      White     Beige  ...           2.5        4.0
# 105952                      Gray     Black  ...           4.4        8.0
#
#         engine_type_encoded  engine_type_Standard  engine_type_Supercharged  \
# 111355                    0                  True                     False
# 182258                    0                  True                     False
# 14147                     0                  True                     False
# 79313                     0                  True                     False
# 101160                    0                  True                     False
# ...                     ...                   ...                       ...
# 71604                     5                 False                     False
# 137137                    0                  True                     False
# 70567                     0                  True                     False
# 94567                     0                  True                     False
# 105952                    0                  True                     False
#
#         engine_type_TFSI  engine_type_TSI  engine_type_Turbo  \
# 111355             False            False              False
# 182258             False            False              False
# 14147              False            False              False
# 79313              False            False              False
# 101160             False            False              False
# ...                  ...              ...                ...
# 71604              False            False              False
# 137137             False            False              False
# 70567              False            False              False
# 94567              False            False              False
# 105952             False            False              False
#
#         engine_type_Turbo, Twin Turbo  engine_type_VTEC
# 111355                          False             False
# 182258                          False             False
# 14147                           False             False
# 79313                           False             False
# 101160                          False             False
# ...                               ...               ...
# 71604                            True             False
# 137137                          False             False
# 70567                           False             False
# 94567                           False             False
# 105952                          False             False
#
# [37707 rows x 31 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ... engine_volume  \
# 0              6-Speed A/T            White   Beige  ...           2.0
# 1              8-Speed A/T           Silver   Black  ...           3.0
# 2       10-Speed Automatic            White   Ebony  ...           3.5
# 3                Automatic  Silician Yellow   Black  ...           2.0
# 4                      A/T             Gray   Black  ...           2.0
# ...                    ...              ...     ...  ...           ...
# 125685         7-Speed A/T            Black   Black  ...           3.0
# 125686           Automatic            White   Black  ...           3.0
# 125687                 A/T            Black   Black  ...           3.0
# 125688                 A/T            Black   Black  ...           3.0
# 125689                 A/T           Silver   Black  ...           5.3
#
#         cylinders  engine_type_encoded  engine_type_Standard  \
# 0             4.0                    0                  True
# 1             6.0                    0                  True
# 2             6.0                    5                 False
# 3             NaN                    2                 False
# 4             4.0                    0                  True
# ...           ...                  ...                   ...
# 125685        6.0                    0                  True
# 125686        NaN                    4                 False
# 125687        6.0                    0                  True
# 125688        6.0                    0                  True
# 125689        8.0                    0                  True
#
#         engine_type_Supercharged  engine_type_TFSI  engine_type_TSI  \
# 0                          False             False            False
# 1                          False             False            False
# 2                          False             False            False
# 3                          False              True            False
# 4                          False             False            False
# ...                          ...               ...              ...
# 125685                     False             False            False
# 125686                     False             False            False
# 125687                     False             False            False
# 125688                     False             False            False
# 125689                     False             False            False
#
#         engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC
# 0                   False                          False             False
# 1                   False                          False             False
# 2                   False                           True             False
# 3                   False                          False             False
# 4                   False                          False             False
# ...                   ...                            ...               ...
# 125685              False                          False             False
# 125686               True                          False             False
# 125687              False                          False             False
# 125688              False                          False             False
# 125689              False                          False             False
#
# [125690 rows x 29 columns]

# %%
df_train_data['engine_type_TSI'].value_counts()
# Out:
# engine_type_TSI
# False    150796
# True         30
# Name: count, dtype: int64

# %%
df_train_data['transmission'].unique()
# Out:
# array(['Transmission w/Dual Shift Mode', 'A/T', '10-Speed A/T',
#        '6-Speed M/T', '6-Speed A/T', '8-Speed A/T', '9-Speed Automatic',
#        '7-Speed A/T', '8-Speed Automatic with Auto-Shift',
#        '8-Speed Automatic', 'Automatic', '9-Speed A/T',
#        'CVT Transmission', '7-Speed M/T',
#        '7-Speed Automatic with Auto-Shift', '10-Speed Automatic', 'M/T',
#        '1-Speed A/T', '4-Speed A/T', '6-Speed Automatic', '5-Speed A/T',
#        '5-Speed M/T', 'Automatic CVT', '1-Speed Automatic',
#        '6-Speed Electronically Controlled Automatic with O', '6-Speed',
#        '6-Speed Manual', '10-Speed Automatic with Overdrive',
#        '6-Speed Automatic with Auto-Shift', '4-Speed Automatic',
#        'Transmission Overdrive Switch', '2', '5-Speed Automatic',
#        'Single-Speed Fixed Gear', 'Variable', 'CVT-F', '–',
#        '9-Speed Automatic with Auto-Shift', '6 Speed Mt',
#        '7-Speed Manual', '2-Speed A/T', '6 Speed At/Mt', 'F', 'Manual',
#        '2-Speed Automatic', '7-Speed Automatic', '8-SPEED AT',
#        '8-Speed Manual', 'SCHEDULED FOR OR IN PRODUCTION', '8-SPEED A/T',
#        '7-Speed DCT Automatic', '7-Speed'], dtype=object)

# %%
# Step 1: Extract the number of gears
def extract_gears(transmission_str):
    match = re.search(r'(\d+)-Speed', transmission_str)
    return int(match.group(1)) if match else 6.0

# Step 2: Determine if the transmission is automatic, manual, or CVT
def extract_transmission_type(transmission_str):
    transmission_str = transmission_str.lower()
    if 'a/t' in transmission_str or 'automatic' in transmission_str:
        return 'Automatic'
    elif 'm/t' in transmission_str or 'manual' in transmission_str:
        return 'Manual'
    elif 'cvt' in transmission_str:
        return 'CVT'
    else:
        return 'Unknown'

# Step 3: Identify additional flags (e.g., Auto-Shift, Overdrive, Dual Shift Mode)
def extract_additional_features(transmission_str):
    features = []
    if 'dual shift mode' in transmission_str.lower():
        features.append('Dual Shift Mode')
    if 'auto-shift' in transmission_str.lower():
        features.append('Auto-Shift')
    if 'overdrive' in transmission_str.lower():
        features.append('Overdrive')
    if 'dct' in transmission_str.lower():
        features.append('DCT')
    if 'fixed gear' in transmission_str.lower():
        features.append('Fixed Gear')

    return ', '.join(features) if features else 'None'

# %%
# Step 4: Apply the functions to the transmission column for training, validation, and test data
for df in [df_train_data, df_val_data, test_data]:
    df['gears'] = df['transmission'].apply(extract_gears)
    df['transmission_type'] = df['transmission'].apply(extract_transmission_type)
    df['additional_features'] = df['transmission'].apply(extract_additional_features)

# Step 5: Check the new columns
print(df_train_data[['transmission', 'gears', 'transmission_type', 'additional_features']].head())
# Out:
#                           transmission  gears transmission_type  \
# 184031  Transmission w/Dual Shift Mode    6.0           Unknown
# 173831                             A/T    6.0         Automatic
# 183819                    10-Speed A/T   10.0         Automatic
# 85525                      6-Speed M/T    6.0            Manual
# 41872                      6-Speed A/T    6.0         Automatic
#
#        additional_features
# 184031     Dual Shift Mode
# 173831                None
# 183819                None
# 85525                 None
# 41872                 None

# %%
# Step 1: Count the unique values and missing values for the 'gears' feature
print("Gears counts:\n", df_train_data['gears'].value_counts(dropna=False))

# Step 2: Count the unique values and missing values for the 'transmission_type' feature
print("\nTransmission Type counts:\n", df_train_data['transmission_type'].value_counts(dropna=False))

# Step 3: Count the unique values and missing values for the 'additional_features' feature
print("\nAdditional Features counts:\n", df_train_data['additional_features'].value_counts(dropna=False))
# Out:
# Gears counts:
#  gears
# 6.0     94116
# 8.0     23701
# 7.0     10471
# 10.0     8961
# 9.0      4997
# 5.0      4611
# 4.0      2102
# 1.0      1789
# 2.0        78
# Name: count, dtype: int64
#
# Transmission Type counts:
#  transmission_type
# Automatic    120217
# Unknown       15908
# Manual        13102
# CVT            1599
# Name: count, dtype: int64
#
# Additional Features counts:
#  additional_features
# None               133740
# Dual Shift Mode     15407
# Auto-Shift           1491
# Overdrive             160
# DCT                    15
# Fixed Gear             13
# Name: count, dtype: int64

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        engine_type_Standard  engine_type_Supercharged  engine_type_TFSI  \
# 184031                 True                     False             False
# 173831                 True                     False             False
# 183819                 True                     False             False
# 85525                  True                     False             False
# 41872                  True                     False             False
# ...                     ...                       ...               ...
# 119879                 True                     False             False
# 103694                 True                     False             False
# 131932                 True                     False             False
# 146867                 True                     False             False
# 121958                False                     False             False
#
#         engine_type_TSI  engine_type_Turbo  engine_type_Turbo, Twin Turbo  \
# 184031            False              False                          False
# 173831            False              False                          False
# 183819            False              False                          False
# 85525             False              False                          False
# 41872             False              False                          False
# ...                 ...                ...                            ...
# 119879            False              False                          False
# 103694            False              False                          False
# 131932            False              False                          False
# 146867            False              False                          False
# 121958            False              False                           True
#
#         engine_type_VTEC  gears  transmission_type  additional_features
# 184031             False    6.0            Unknown      Dual Shift Mode
# 173831             False    6.0          Automatic                 None
# 183819             False   10.0          Automatic                 None
# 85525              False    6.0             Manual                 None
# 41872              False    6.0          Automatic                 None
# ...                  ...    ...                ...                  ...
# 119879             False    6.0             Manual                 None
# 103694             False    7.0          Automatic                 None
# 131932             False    8.0          Automatic                 None
# 146867             False    7.0          Automatic                 None
# 121958             False    8.0          Automatic           Auto-Shift
#
# [150826 rows x 34 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... engine_type_Standard  \
# 111355  Sunset Drift Chromaflair  Graphite  ...                 True
# 182258                      Gold     Beige  ...                 True
# 14147                  Dark Moss  Chestnut  ...                 True
# 79313                      White     Black  ...                 True
# 101160                      Gray     Black  ...                 True
# ...                          ...       ...  ...                  ...
# 71604                       Gray   Ceramic  ...                False
# 137137                     White     Black  ...                 True
# 70567                        Red      Gray  ...                 True
# 94567                      White     Beige  ...                 True
# 105952                      Gray     Black  ...                 True
#
#         engine_type_Supercharged  engine_type_TFSI  engine_type_TSI  \
# 111355                     False             False            False
# 182258                     False             False            False
# 14147                      False             False            False
# 79313                      False             False            False
# 101160                     False             False            False
# ...                          ...               ...              ...
# 71604                      False             False            False
# 137137                     False             False            False
# 70567                      False             False            False
# 94567                      False             False            False
# 105952                     False             False            False
#
#         engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC  \
# 111355              False                          False             False
# 182258              False                          False             False
# 14147               False                          False             False
# 79313               False                          False             False
# 101160              False                          False             False
# ...                   ...                            ...               ...
# 71604               False                           True             False
# 137137              False                          False             False
# 70567               False                          False             False
# 94567               False                          False             False
# 105952              False                          False             False
#
#         gears  transmission_type  additional_features
# 111355    6.0          Automatic                 None
# 182258    6.0          Automatic                 None
# 14147     9.0          Automatic                 None
# 79313     8.0          Automatic                 None
# 101160    8.0          Automatic                 None
# ...       ...                ...                  ...
# 71604    10.0          Automatic                 None
# 137137    8.0          Automatic                 None
# 70567     6.0          Automatic                 None
# 94567     6.0          Automatic                 None
# 105952    6.0             Manual                 None
#
# [37707 rows x 34 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ... engine_type_Standard  \
# 0              6-Speed A/T            White   Beige  ...                 True
# 1              8-Speed A/T           Silver   Black  ...                 True
# 2       10-Speed Automatic            White   Ebony  ...                False
# 3                Automatic  Silician Yellow   Black  ...                False
# 4                      A/T             Gray   Black  ...                 True
# ...                    ...              ...     ...  ...                  ...
# 125685         7-Speed A/T            Black   Black  ...                 True
# 125686           Automatic            White   Black  ...                False
# 125687                 A/T            Black   Black  ...                 True
# 125688                 A/T            Black   Black  ...                 True
# 125689                 A/T           Silver   Black  ...                 True
#
#         engine_type_Supercharged  engine_type_TFSI  engine_type_TSI  \
# 0                          False             False            False
# 1                          False             False            False
# 2                          False             False            False
# 3                          False              True            False
# 4                          False             False            False
# ...                          ...               ...              ...
# 125685                     False             False            False
# 125686                     False             False            False
# 125687                     False             False            False
# 125688                     False             False            False
# 125689                     False             False            False
#
#         engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC  \
# 0                   False                          False             False
# 1                   False                          False             False
# 2                   False                           True             False
# 3                   False                          False             False
# 4                   False                          False             False
# ...                   ...                            ...               ...
# 125685              False                          False             False
# 125686               True                          False             False
# 125687              False                          False             False
# 125688              False                          False             False
# 125689              False                          False             False
#
#         gears  transmission_type  additional_features
# 0         6.0          Automatic                 None
# 1         8.0          Automatic                 None
# 2        10.0          Automatic                 None
# 3         6.0          Automatic                 None
# 4         6.0          Automatic                 None
# ...       ...                ...                  ...
# 125685    7.0          Automatic                 None
# 125686    6.0          Automatic                 None
# 125687    6.0          Automatic                 None
# 125688    6.0          Automatic                 None
# 125689    6.0          Automatic                 None
#
# [125690 rows x 32 columns]

# %%
# Step 1: Initialize the label encoder
label_encoder = LabelEncoder()

# Step 2: Fit the label encoder on the training data
df_train_data['transmission_type_label'] = label_encoder.fit_transform(df_train_data['transmission_type'])

# Step 3: Define a function to handle unseen labels
def encode_with_label_encoder(label_encoder, series):
    # If the label is not in the encoder, return -1 (or some other value to indicate an unseen label)
    return series.apply(lambda x: label_encoder.transform([x])[0] if x in label_encoder.classes_ else -1)

# Step 4: Apply the encoder to validation and test data (handle unseen labels)
df_val_data['transmission_type_label'] = encode_with_label_encoder(label_encoder, df_val_data['transmission_type'])
test_data['transmission_type_label'] = encode_with_label_encoder(label_encoder, test_data['transmission_type'])

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        engine_type_Supercharged  engine_type_TFSI  engine_type_TSI  \
# 184031                    False             False            False
# 173831                    False             False            False
# 183819                    False             False            False
# 85525                     False             False            False
# 41872                     False             False            False
# ...                         ...               ...              ...
# 119879                    False             False            False
# 103694                    False             False            False
# 131932                    False             False            False
# 146867                    False             False            False
# 121958                    False             False            False
#
#         engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC  \
# 184031              False                          False             False
# 173831              False                          False             False
# 183819              False                          False             False
# 85525               False                          False             False
# 41872               False                          False             False
# ...                   ...                            ...               ...
# 119879              False                          False             False
# 103694              False                          False             False
# 131932              False                          False             False
# 146867              False                          False             False
# 121958              False                           True             False
#
#         gears  transmission_type  additional_features  transmission_type_label
# 184031    6.0            Unknown      Dual Shift Mode                        3
# 173831    6.0          Automatic                 None                        0
# 183819   10.0          Automatic                 None                        0
# 85525     6.0             Manual                 None                        2
# 41872     6.0          Automatic                 None                        0
# ...       ...                ...                  ...                      ...
# 119879    6.0             Manual                 None                        2
# 103694    7.0          Automatic                 None                        0
# 131932    8.0          Automatic                 None                        0
# 146867    7.0          Automatic                 None                        0
# 121958    8.0          Automatic           Auto-Shift                        0
#
# [150826 rows x 35 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... engine_type_Supercharged  \
# 111355  Sunset Drift Chromaflair  Graphite  ...                    False
# 182258                      Gold     Beige  ...                    False
# 14147                  Dark Moss  Chestnut  ...                    False
# 79313                      White     Black  ...                    False
# 101160                      Gray     Black  ...                    False
# ...                          ...       ...  ...                      ...
# 71604                       Gray   Ceramic  ...                    False
# 137137                     White     Black  ...                    False
# 70567                        Red      Gray  ...                    False
# 94567                      White     Beige  ...                    False
# 105952                      Gray     Black  ...                    False
#
#         engine_type_TFSI  engine_type_TSI  engine_type_Turbo  \
# 111355             False            False              False
# 182258             False            False              False
# 14147              False            False              False
# 79313              False            False              False
# 101160             False            False              False
# ...                  ...              ...                ...
# 71604              False            False              False
# 137137             False            False              False
# 70567              False            False              False
# 94567              False            False              False
# 105952             False            False              False
#
#         engine_type_Turbo, Twin Turbo  engine_type_VTEC  gears  \
# 111355                          False             False    6.0
# 182258                          False             False    6.0
# 14147                           False             False    9.0
# 79313                           False             False    8.0
# 101160                          False             False    8.0
# ...                               ...               ...    ...
# 71604                            True             False   10.0
# 137137                          False             False    8.0
# 70567                           False             False    6.0
# 94567                           False             False    6.0
# 105952                          False             False    6.0
#
#         transmission_type  additional_features  transmission_type_label
# 111355          Automatic                 None                        0
# 182258          Automatic                 None                        0
# 14147           Automatic                 None                        0
# 79313           Automatic                 None                        0
# 101160          Automatic                 None                        0
# ...                   ...                  ...                      ...
# 71604           Automatic                 None                        0
# 137137          Automatic                 None                        0
# 70567           Automatic                 None                        0
# 94567           Automatic                 None                        0
# 105952             Manual                 None                        2
#
# [37707 rows x 35 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ...  \
# 0              6-Speed A/T            White   Beige  ...
# 1              8-Speed A/T           Silver   Black  ...
# 2       10-Speed Automatic            White   Ebony  ...
# 3                Automatic  Silician Yellow   Black  ...
# 4                      A/T             Gray   Black  ...
# ...                    ...              ...     ...  ...
# 125685         7-Speed A/T            Black   Black  ...
# 125686           Automatic            White   Black  ...
# 125687                 A/T            Black   Black  ...
# 125688                 A/T            Black   Black  ...
# 125689                 A/T           Silver   Black  ...
#
#        engine_type_Supercharged  engine_type_TFSI  engine_type_TSI  \
# 0                         False             False            False
# 1                         False             False            False
# 2                         False             False            False
# 3                         False              True            False
# 4                         False             False            False
# ...                         ...               ...              ...
# 125685                    False             False            False
# 125686                    False             False            False
# 125687                    False             False            False
# 125688                    False             False            False
# 125689                    False             False            False
#
#         engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC  \
# 0                   False                          False             False
# 1                   False                          False             False
# 2                   False                           True             False
# 3                   False                          False             False
# 4                   False                          False             False
# ...                   ...                            ...               ...
# 125685              False                          False             False
# 125686               True                          False             False
# 125687              False                          False             False
# 125688              False                          False             False
# 125689              False                          False             False
#
#         gears  transmission_type  additional_features  transmission_type_label
# 0         6.0          Automatic                 None                        0
# 1         8.0          Automatic                 None                        0
# 2        10.0          Automatic                 None                        0
# 3         6.0          Automatic                 None                        0
# 4         6.0          Automatic                 None                        0
# ...       ...                ...                  ...                      ...
# 125685    7.0          Automatic                 None                        0
# 125686    6.0          Automatic                 None                        0
# 125687    6.0          Automatic                 None                        0
# 125688    6.0          Automatic                 None                        0
# 125689    6.0          Automatic                 None                        0
#
# [125690 rows x 33 columns]

# %%
# Step 1: Perform one-hot encoding on the 'transmission_type' column in the training data
df_train_data = pd.get_dummies(df_train_data, columns=['transmission_type'], prefix='transmission_type', drop_first=False)

# Step 2: Extract the one-hot columns generated in the training data
one_hot_columns_transmission = [col for col in df_train_data.columns if 'transmission_type_' in col]

# Step 3: Apply one-hot encoding to the validation and test data, ensuring they have the same columns
df_val_data = pd.get_dummies(df_val_data, columns=['transmission_type'], prefix='transmission_type', drop_first=False)
df_val_data = df_val_data.reindex(columns=df_train_data.columns, fill_value=0)  # Reindex to match training data columns

# Remove 'price' and 'log_price' from the list of columns to reindex on
train_columns = df_train_data.columns.drop(['price', 'log_price'])

# Step 3: Check for duplicate columns in train data and remove them if needed
train_columns = train_columns.drop_duplicates()

test_data = pd.get_dummies(test_data, columns=['transmission_type'], prefix='transmission_type', drop_first=False)
test_data = test_data.reindex(columns=train_columns, fill_value=0)  # Reindex to match training data columns

# The original 'transmission_type' column will be retained alongside the one-hot encoded columns if needed

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        engine_type_Turbo  engine_type_Turbo, Twin Turbo  engine_type_VTEC  \
# 184031             False                          False             False
# 173831             False                          False             False
# 183819             False                          False             False
# 85525              False                          False             False
# 41872              False                          False             False
# ...                  ...                            ...               ...
# 119879             False                          False             False
# 103694             False                          False             False
# 131932             False                          False             False
# 146867             False                          False             False
# 121958             False                           True             False
#
#         gears  additional_features  transmission_type_label  \
# 184031    6.0      Dual Shift Mode                        3
# 173831    6.0                 None                        0
# 183819   10.0                 None                        0
# 85525     6.0                 None                        2
# 41872     6.0                 None                        0
# ...       ...                  ...                      ...
# 119879    6.0                 None                        2
# 103694    7.0                 None                        0
# 131932    8.0                 None                        0
# 146867    7.0                 None                        0
# 121958    8.0           Auto-Shift                        0
#
#         transmission_type_Automatic  transmission_type_CVT  \
# 184031                        False                  False
# 173831                         True                  False
# 183819                         True                  False
# 85525                         False                  False
# 41872                          True                  False
# ...                             ...                    ...
# 119879                        False                  False
# 103694                         True                  False
# 131932                         True                  False
# 146867                         True                  False
# 121958                         True                  False
#
#         transmission_type_Manual  transmission_type_Unknown
# 184031                     False                       True
# 173831                     False                      False
# 183819                     False                      False
# 85525                       True                      False
# 41872                      False                      False
# ...                          ...                        ...
# 119879                      True                      False
# 103694                     False                      False
# 131932                     False                      False
# 146867                     False                      False
# 121958                     False                      False
#
# [150826 rows x 38 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... engine_type_Turbo  \
# 111355  Sunset Drift Chromaflair  Graphite  ...             False
# 182258                      Gold     Beige  ...             False
# 14147                  Dark Moss  Chestnut  ...             False
# 79313                      White     Black  ...             False
# 101160                      Gray     Black  ...             False
# ...                          ...       ...  ...               ...
# 71604                       Gray   Ceramic  ...             False
# 137137                     White     Black  ...             False
# 70567                        Red      Gray  ...             False
# 94567                      White     Beige  ...             False
# 105952                      Gray     Black  ...             False
#
#         engine_type_Turbo, Twin Turbo  engine_type_VTEC  gears  \
# 111355                          False             False    6.0
# 182258                          False             False    6.0
# 14147                           False             False    9.0
# 79313                           False             False    8.0
# 101160                          False             False    8.0
# ...                               ...               ...    ...
# 71604                            True             False   10.0
# 137137                          False             False    8.0
# 70567                           False             False    6.0
# 94567                           False             False    6.0
# 105952                          False             False    6.0
#
#         additional_features  transmission_type_label  \
# 111355                 None                        0
# 182258                 None                        0
# 14147                  None                        0
# 79313                  None                        0
# 101160                 None                        0
# ...                     ...                      ...
# 71604                  None                        0
# 137137                 None                        0
# 70567                  None                        0
# 94567                  None                        0
# 105952                 None                        2
#
#         transmission_type_Automatic  transmission_type_CVT  \
# 111355                         True                  False
# 182258                         True                  False
# 14147                          True                  False
# 79313                          True                  False
# 101160                         True                  False
# ...                             ...                    ...
# 71604                          True                  False
# 137137                         True                  False
# 70567                          True                  False
# 94567                          True                  False
# 105952                        False                  False
#
#         transmission_type_Manual  transmission_type_Unknown
# 111355                     False                      False
# 182258                     False                      False
# 14147                      False                      False
# 79313                      False                      False
# 101160                     False                      False
# ...                          ...                        ...
# 71604                      False                      False
# 137137                     False                      False
# 70567                      False                      False
# 94567                      False                      False
# 105952                      True                      False
#
# [37707 rows x 38 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ... engine_type_Turbo  \
# 0              6-Speed A/T            White   Beige  ...             False
# 1              8-Speed A/T           Silver   Black  ...             False
# 2       10-Speed Automatic            White   Ebony  ...             False
# 3                Automatic  Silician Yellow   Black  ...             False
# 4                      A/T             Gray   Black  ...             False
# ...                    ...              ...     ...  ...               ...
# 125685         7-Speed A/T            Black   Black  ...             False
# 125686           Automatic            White   Black  ...              True
# 125687                 A/T            Black   Black  ...             False
# 125688                 A/T            Black   Black  ...             False
# 125689                 A/T           Silver   Black  ...             False
#
#         engine_type_Turbo, Twin Turbo  engine_type_VTEC  gears  \
# 0                               False             False    6.0
# 1                               False             False    8.0
# 2                                True             False   10.0
# 3                               False             False    6.0
# 4                               False             False    6.0
# ...                               ...               ...    ...
# 125685                          False             False    7.0
# 125686                          False             False    6.0
# 125687                          False             False    6.0
# 125688                          False             False    6.0
# 125689                          False             False    6.0
#
#         additional_features  transmission_type_label  \
# 0                      None                        0
# 1                      None                        0
# 2                      None                        0
# 3                      None                        0
# 4                      None                        0
# ...                     ...                      ...
# 125685                 None                        0
# 125686                 None                        0
# 125687                 None                        0
# 125688                 None                        0
# 125689                 None                        0
#
#         transmission_type_Automatic  transmission_type_CVT  \
# 0                              True                  False
# 1                              True                  False
# 2                              True                  False
# 3                              True                  False
# 4                              True                  False
# ...                             ...                    ...
# 125685                         True                  False
# 125686                         True                  False
# 125687                         True                  False
# 125688                         True                  False
# 125689                         True                  False
#
#         transmission_type_Manual  transmission_type_Unknown
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 125685                     False                      False
# 125686                     False                      False
# 125687                     False                      False
# 125688                     False                      False
# 125689                     False                      False
#
# [125690 rows x 36 columns]

# %%
test_data['additional_features'].value_counts(dropna=False)
# Out:
# additional_features
# None               111445
# Dual Shift Mode     12824
# Auto-Shift           1235
# Overdrive             163
# Fixed Gear             12
# DCT                    11
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the Label Encoder
le_additional_features = LabelEncoder()

# Step 1: Fit the label encoder on the training data 'additional_features'
df_train_data['additional_features_encoded'] = le_additional_features.fit_transform(df_train_data['additional_features'])

# Step 2: Encode 'additional_features' in the validation and test sets using the trained encoder
# Handle unseen labels by assigning -1 if the value is not in the training data
df_val_data['additional_features_encoded'] = df_val_data['additional_features'].apply(
    lambda x: le_additional_features.transform([x])[0] if x in le_additional_features.classes_ else -1
)

test_data['additional_features_encoded'] = test_data['additional_features'].apply(
    lambda x: le_additional_features.transform([x])[0] if x in le_additional_features.classes_ else -1
)

# Now 'additional_features_encoded' will have label-encoded values in all datasets

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        engine_type_Turbo, Twin Turbo  engine_type_VTEC  gears  \
# 184031                         False             False    6.0
# 173831                         False             False    6.0
# 183819                         False             False   10.0
# 85525                          False             False    6.0
# 41872                          False             False    6.0
# ...                              ...               ...    ...
# 119879                         False             False    6.0
# 103694                         False             False    7.0
# 131932                         False             False    8.0
# 146867                         False             False    7.0
# 121958                          True             False    8.0
#
#         additional_features  transmission_type_label  \
# 184031      Dual Shift Mode                        3
# 173831                 None                        0
# 183819                 None                        0
# 85525                  None                        2
# 41872                  None                        0
# ...                     ...                      ...
# 119879                 None                        2
# 103694                 None                        0
# 131932                 None                        0
# 146867                 None                        0
# 121958           Auto-Shift                        0
#
#         transmission_type_Automatic  transmission_type_CVT  \
# 184031                        False                  False
# 173831                         True                  False
# 183819                         True                  False
# 85525                         False                  False
# 41872                          True                  False
# ...                             ...                    ...
# 119879                        False                  False
# 103694                         True                  False
# 131932                         True                  False
# 146867                         True                  False
# 121958                         True                  False
#
#         transmission_type_Manual  transmission_type_Unknown  \
# 184031                     False                       True
# 173831                     False                      False
# 183819                     False                      False
# 85525                       True                      False
# 41872                      False                      False
# ...                          ...                        ...
# 119879                      True                      False
# 103694                     False                      False
# 131932                     False                      False
# 146867                     False                      False
# 121958                     False                      False
#
#         additional_features_encoded
# 184031                            2
# 173831                            4
# 183819                            4
# 85525                             4
# 41872                             4
# ...                             ...
# 119879                            4
# 103694                            4
# 131932                            4
# 146867                            4
# 121958                            0
#
# [150826 rows x 39 columns]

# %%
# Step 1: Perform one-hot encoding on the 'additional_features' column in the training data
df_train_data = pd.get_dummies(df_train_data, columns=['additional_features'], prefix='additional_features', drop_first=False)

# Step 2: Extract the one-hot columns generated in the training data
one_hot_columns_additional = [col for col in df_train_data.columns if 'additional_features_' in col]

# Remove 'price' and 'log_price' from the list of columns for test data
train_columns_without_price = df_train_data.columns.drop(['price', 'log_price'])

# Step 3: Apply one-hot encoding to the validation data
df_val_data = pd.get_dummies(df_val_data, columns=['additional_features'], prefix='additional_features', drop_first=False)
df_val_data = df_val_data.reindex(columns=df_train_data.columns, fill_value=0)

# Step 4: Apply one-hot encoding to the test data and exclude 'price' and 'log_price' columns
test_data = pd.get_dummies(test_data, columns=['additional_features'], prefix='additional_features', drop_first=False)
test_data = test_data.reindex(columns=train_columns_without_price, fill_value=0)

# Now the 'additional_features' column is one-hot encoded, and 'price' and 'log_price' are excluded from the test dataset

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        transmission_type_CVT  transmission_type_Manual  \
# 184031                 False                     False
# 173831                 False                     False
# 183819                 False                     False
# 85525                  False                      True
# 41872                  False                     False
# ...                      ...                       ...
# 119879                 False                      True
# 103694                 False                     False
# 131932                 False                     False
# 146867                 False                     False
# 121958                 False                     False
#
#         transmission_type_Unknown  additional_features_encoded  \
# 184031                       True                            2
# 173831                      False                            4
# 183819                      False                            4
# 85525                       False                            4
# 41872                       False                            4
# ...                           ...                          ...
# 119879                      False                            4
# 103694                      False                            4
# 131932                      False                            4
# 146867                      False                            4
# 121958                      False                            0
#
#         additional_features_Auto-Shift  additional_features_DCT  \
# 184031                           False                    False
# 173831                           False                    False
# 183819                           False                    False
# 85525                            False                    False
# 41872                            False                    False
# ...                                ...                      ...
# 119879                           False                    False
# 103694                           False                    False
# 131932                           False                    False
# 146867                           False                    False
# 121958                            True                    False
#
#         additional_features_Dual Shift Mode  additional_features_Fixed Gear  \
# 184031                                 True                           False
# 173831                                False                           False
# 183819                                False                           False
# 85525                                 False                           False
# 41872                                 False                           False
# ...                                     ...                             ...
# 119879                                False                           False
# 103694                                False                           False
# 131932                                False                           False
# 146867                                False                           False
# 121958                                False                           False
#
#         additional_features_None  additional_features_Overdrive
# 184031                     False                          False
# 173831                      True                          False
# 183819                      True                          False
# 85525                       True                          False
# 41872                       True                          False
# ...                          ...                            ...
# 119879                      True                          False
# 103694                      True                          False
# 131932                      True                          False
# 146867                      True                          False
# 121958                     False                          False
#
# [150826 rows x 44 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... transmission_type_CVT  \
# 111355  Sunset Drift Chromaflair  Graphite  ...                 False
# 182258                      Gold     Beige  ...                 False
# 14147                  Dark Moss  Chestnut  ...                 False
# 79313                      White     Black  ...                 False
# 101160                      Gray     Black  ...                 False
# ...                          ...       ...  ...                   ...
# 71604                       Gray   Ceramic  ...                 False
# 137137                     White     Black  ...                 False
# 70567                        Red      Gray  ...                 False
# 94567                      White     Beige  ...                 False
# 105952                      Gray     Black  ...                 False
#
#         transmission_type_Manual  transmission_type_Unknown  \
# 111355                     False                      False
# 182258                     False                      False
# 14147                      False                      False
# 79313                      False                      False
# 101160                     False                      False
# ...                          ...                        ...
# 71604                      False                      False
# 137137                     False                      False
# 70567                      False                      False
# 94567                      False                      False
# 105952                      True                      False
#
#         additional_features_encoded  additional_features_Auto-Shift  \
# 111355                            4                           False
# 182258                            4                           False
# 14147                             4                           False
# 79313                             4                           False
# 101160                            4                           False
# ...                             ...                             ...
# 71604                             4                           False
# 137137                            4                           False
# 70567                             4                           False
# 94567                             4                           False
# 105952                            4                           False
#
#         additional_features_DCT  additional_features_Dual Shift Mode  \
# 111355                    False                                False
# 182258                    False                                False
# 14147                     False                                False
# 79313                     False                                False
# 101160                    False                                False
# ...                         ...                                  ...
# 71604                     False                                False
# 137137                    False                                False
# 70567                     False                                False
# 94567                     False                                False
# 105952                    False                                False
#
#         additional_features_Fixed Gear  additional_features_None  \
# 111355                           False                      True
# 182258                           False                      True
# 14147                            False                      True
# 79313                            False                      True
# 101160                           False                      True
# ...                                ...                       ...
# 71604                            False                      True
# 137137                           False                      True
# 70567                            False                      True
# 94567                            False                      True
# 105952                           False                      True
#
#         additional_features_Overdrive
# 111355                          False
# 182258                          False
# 14147                           False
# 79313                           False
# 101160                          False
# ...                               ...
# 71604                           False
# 137137                          False
# 70567                           False
# 94567                           False
# 105952                          False
#
# [37707 rows x 44 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ...  \
# 0              6-Speed A/T            White   Beige  ...
# 1              8-Speed A/T           Silver   Black  ...
# 2       10-Speed Automatic            White   Ebony  ...
# 3                Automatic  Silician Yellow   Black  ...
# 4                      A/T             Gray   Black  ...
# ...                    ...              ...     ...  ...
# 125685         7-Speed A/T            Black   Black  ...
# 125686           Automatic            White   Black  ...
# 125687                 A/T            Black   Black  ...
# 125688                 A/T            Black   Black  ...
# 125689                 A/T           Silver   Black  ...
#
#        transmission_type_CVT  transmission_type_Manual  \
# 0                      False                     False
# 1                      False                     False
# 2                      False                     False
# 3                      False                     False
# 4                      False                     False
# ...                      ...                       ...
# 125685                 False                     False
# 125686                 False                     False
# 125687                 False                     False
# 125688                 False                     False
# 125689                 False                     False
#
#         transmission_type_Unknown  additional_features_encoded  \
# 0                           False                            4
# 1                           False                            4
# 2                           False                            4
# 3                           False                            4
# 4                           False                            4
# ...                           ...                          ...
# 125685                      False                            4
# 125686                      False                            4
# 125687                      False                            4
# 125688                      False                            4
# 125689                      False                            4
#
#         additional_features_Auto-Shift  additional_features_DCT  \
# 0                                False                    False
# 1                                False                    False
# 2                                False                    False
# 3                                False                    False
# 4                                False                    False
# ...                                ...                      ...
# 125685                           False                    False
# 125686                           False                    False
# 125687                           False                    False
# 125688                           False                    False
# 125689                           False                    False
#
#         additional_features_Dual Shift Mode  additional_features_Fixed Gear  \
# 0                                     False                           False
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                           False
# ...                                     ...                             ...
# 125685                                False                           False
# 125686                                False                           False
# 125687                                False                           False
# 125688                                False                           False
# 125689                                False                           False
#
#         additional_features_None  additional_features_Overdrive
# 0                           True                          False
# 1                           True                          False
# 2                           True                          False
# 3                           True                          False
# 4                           True                          False
# ...                          ...                            ...
# 125685                      True                          False
# 125686                      True                          False
# 125687                      True                          False
# 125688                      True                          False
# 125689                      True                          False
#
# [125690 rows x 42 columns]

# %%
import webcolors

# Define a mapping of color names to RGB values
def get_rgb(color_name):
    try:
        return webcolors.name_to_rgb(color_name)
    except ValueError:
        return (0, 0, 0)  # Return black as a fallback for unknown colors

# Apply the RGB conversion function to the 'ext_col' column
df_train_data['ext_col_rgb'] = df_train_data['ext_col'].apply(get_rgb)

# Split the RGB values into separate columns
df_train_data['ext_col_R'] = df_train_data['ext_col_rgb'].apply(lambda x: x[0])
df_train_data['ext_col_G'] = df_train_data['ext_col_rgb'].apply(lambda x: x[1])
df_train_data['ext_col_B'] = df_train_data['ext_col_rgb'].apply(lambda x: x[2])

# Do the same for validation and test data
df_val_data['ext_col_rgb'] = df_val_data['ext_col'].apply(get_rgb)
df_val_data['ext_col_R'] = df_val_data['ext_col_rgb'].apply(lambda x: x[0])
df_val_data['ext_col_G'] = df_val_data['ext_col_rgb'].apply(lambda x: x[1])
df_val_data['ext_col_B'] = df_val_data['ext_col_rgb'].apply(lambda x: x[2])

test_data['ext_col_rgb'] = test_data['ext_col'].apply(get_rgb)
test_data['ext_col_R'] = test_data['ext_col_rgb'].apply(lambda x: x[0])
test_data['ext_col_G'] = test_data['ext_col_rgb'].apply(lambda x: x[1])
test_data['ext_col_B'] = test_data['ext_col_rgb'].apply(lambda x: x[2])

# %%
# Drop the intermediate 'ext_col_rgb' column
df_train_data.drop('ext_col_rgb', axis=1, inplace=True)
df_val_data.drop('ext_col_rgb', axis=1, inplace=True)
test_data.drop('ext_col_rgb', axis=1, inplace=True)

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        additional_features_encoded  additional_features_Auto-Shift  \
# 184031                           2                           False
# 173831                           4                           False
# 183819                           4                           False
# 85525                            4                           False
# 41872                            4                           False
# ...                            ...                             ...
# 119879                           4                           False
# 103694                           4                           False
# 131932                           4                           False
# 146867                           4                           False
# 121958                           0                            True
#
#         additional_features_DCT  additional_features_Dual Shift Mode  \
# 184031                    False                                 True
# 173831                    False                                False
# 183819                    False                                False
# 85525                     False                                False
# 41872                     False                                False
# ...                         ...                                  ...
# 119879                    False                                False
# 103694                    False                                False
# 131932                    False                                False
# 146867                    False                                False
# 121958                    False                                False
#
#         additional_features_Fixed Gear  additional_features_None  \
# 184031                           False                     False
# 173831                           False                      True
# 183819                           False                      True
# 85525                            False                      True
# 41872                            False                      True
# ...                                ...                       ...
# 119879                           False                      True
# 103694                           False                      True
# 131932                           False                      True
# 146867                           False                      True
# 121958                           False                     False
#
#         additional_features_Overdrive  ext_col_R  ext_col_G  ext_col_B
# 184031                          False        128        128        128
# 173831                          False        192        192        192
# 183819                          False        128        128        128
# 85525                           False          0          0          0
# 41872                           False        255          0          0
# ...                               ...        ...        ...        ...
# 119879                          False        255          0          0
# 103694                          False          0          0          0
# 131932                          False          0          0          0
# 146867                          False          0          0          0
# 121958                          False          0          0          0
#
# [150826 rows x 47 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ... additional_features_encoded  \
# 111355  Sunset Drift Chromaflair  Graphite  ...                           4
# 182258                      Gold     Beige  ...                           4
# 14147                  Dark Moss  Chestnut  ...                           4
# 79313                      White     Black  ...                           4
# 101160                      Gray     Black  ...                           4
# ...                          ...       ...  ...                         ...
# 71604                       Gray   Ceramic  ...                           4
# 137137                     White     Black  ...                           4
# 70567                        Red      Gray  ...                           4
# 94567                      White     Beige  ...                           4
# 105952                      Gray     Black  ...                           4
#
#         additional_features_Auto-Shift  additional_features_DCT  \
# 111355                           False                    False
# 182258                           False                    False
# 14147                            False                    False
# 79313                            False                    False
# 101160                           False                    False
# ...                                ...                      ...
# 71604                            False                    False
# 137137                           False                    False
# 70567                            False                    False
# 94567                            False                    False
# 105952                           False                    False
#
#         additional_features_Dual Shift Mode  additional_features_Fixed Gear  \
# 111355                                False                           False
# 182258                                False                           False
# 14147                                 False                           False
# 79313                                 False                           False
# 101160                                False                           False
# ...                                     ...                             ...
# 71604                                 False                           False
# 137137                                False                           False
# 70567                                 False                           False
# 94567                                 False                           False
# 105952                                False                           False
#
#         additional_features_None  additional_features_Overdrive  ext_col_R  \
# 111355                      True                          False          0
# 182258                      True                          False        255
# 14147                       True                          False          0
# 79313                       True                          False        255
# 101160                      True                          False        128
# ...                          ...                            ...        ...
# 71604                       True                          False        128
# 137137                      True                          False        255
# 70567                       True                          False        255
# 94567                       True                          False        255
# 105952                      True                          False        128
#
#         ext_col_G  ext_col_B
# 111355          0          0
# 182258        215          0
# 14147           0          0
# 79313         255        255
# 101160        128        128
# ...           ...        ...
# 71604         128        128
# 137137        255        255
# 70567           0          0
# 94567         255        255
# 105952        128        128
#
# [37707 rows x 47 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ...  \
# 0              6-Speed A/T            White   Beige  ...
# 1              8-Speed A/T           Silver   Black  ...
# 2       10-Speed Automatic            White   Ebony  ...
# 3                Automatic  Silician Yellow   Black  ...
# 4                      A/T             Gray   Black  ...
# ...                    ...              ...     ...  ...
# 125685         7-Speed A/T            Black   Black  ...
# 125686           Automatic            White   Black  ...
# 125687                 A/T            Black   Black  ...
# 125688                 A/T            Black   Black  ...
# 125689                 A/T           Silver   Black  ...
#
#        additional_features_encoded  additional_features_Auto-Shift  \
# 0                                4                           False
# 1                                4                           False
# 2                                4                           False
# 3                                4                           False
# 4                                4                           False
# ...                            ...                             ...
# 125685                           4                           False
# 125686                           4                           False
# 125687                           4                           False
# 125688                           4                           False
# 125689                           4                           False
#
#         additional_features_DCT  additional_features_Dual Shift Mode  \
# 0                         False                                False
# 1                         False                                False
# 2                         False                                False
# 3                         False                                False
# 4                         False                                False
# ...                         ...                                  ...
# 125685                    False                                False
# 125686                    False                                False
# 125687                    False                                False
# 125688                    False                                False
# 125689                    False                                False
#
#         additional_features_Fixed Gear  additional_features_None  \
# 0                                False                      True
# 1                                False                      True
# 2                                False                      True
# 3                                False                      True
# 4                                False                      True
# ...                                ...                       ...
# 125685                           False                      True
# 125686                           False                      True
# 125687                           False                      True
# 125688                           False                      True
# 125689                           False                      True
#
#         additional_features_Overdrive  ext_col_R  ext_col_G  ext_col_B
# 0                               False        255        255        255
# 1                               False        192        192        192
# 2                               False        255        255        255
# 3                               False          0          0          0
# 4                               False        128        128        128
# ...                               ...        ...        ...        ...
# 125685                          False          0          0          0
# 125686                          False        255        255        255
# 125687                          False          0          0          0
# 125688                          False          0          0          0
# 125689                          False        192        192        192
#
# [125690 rows x 45 columns]

# %%
# Apply the RGB conversion function to the 'int_col' column
df_train_data['int_col_rgb'] = df_train_data['int_col'].apply(get_rgb)

# Split the RGB values into separate columns
df_train_data['int_col_R'] = df_train_data['int_col_rgb'].apply(lambda x: x[0])
df_train_data['int_col_G'] = df_train_data['int_col_rgb'].apply(lambda x: x[1])
df_train_data['int_col_B'] = df_train_data['int_col_rgb'].apply(lambda x: x[2])

# Apply the same for validation and test data
df_val_data['int_col_rgb'] = df_val_data['int_col'].apply(get_rgb)
df_val_data['int_col_R'] = df_val_data['int_col_rgb'].apply(lambda x: x[0])
df_val_data['int_col_G'] = df_val_data['int_col_rgb'].apply(lambda x: x[1])
df_val_data['int_col_B'] = df_val_data['int_col_rgb'].apply(lambda x: x[2])

test_data['int_col_rgb'] = test_data['int_col'].apply(get_rgb)
test_data['int_col_R'] = test_data['int_col_rgb'].apply(lambda x: x[0])
test_data['int_col_G'] = test_data['int_col_rgb'].apply(lambda x: x[1])
test_data['int_col_B'] = test_data['int_col_rgb'].apply(lambda x: x[2])

# %%
# Drop the intermediate 'int_col_rgb' column
df_train_data.drop('int_col_rgb', axis=1, inplace=True)
df_val_data.drop('int_col_rgb', axis=1, inplace=True)
test_data.drop('int_col_rgb', axis=1, inplace=True)

# %%
df_train_data
# Out:
#             id          brand                         model  model_year  \
# 184031  184031  Mercedes-Benz      GLA-Class GLA 250 4MATIC        2017
# 173831  173831         Nissan                   Frontier SV        2003
# 183819  183819           Ford                     F-150 XLT        2020
# 85525    85525        Hyundai                Elantra N Base        2023
# 41872    41872          Dodge  Charger SRT Hellcat Widebody        2023
# ...        ...            ...                           ...         ...
# 119879  119879      Chevrolet                 Corvette Base        2007
# 103694  103694            BMW                         740 i        2019
# 131932  131932        Porsche                911 Carrera 4S        2021
# 146867  146867  Mercedes-Benz                M-Class ML 350        2011
# 121958  121958       Maserati                     MC20 Base        2023
#
#         milage      fuel_type  \
# 184031   61675  E85 Flex Fuel
# 173831  185000       Gasoline
# 183819   92000       Gasoline
# 85525     5483       Gasoline
# 41872     5000       Gasoline
# ...        ...            ...
# 119879   89106       Gasoline
# 103694   57300       Gasoline
# 131932   31500       Gasoline
# 146867  186000       Gasoline
# 121958    5989       Gasoline
#
#                                                    engine  \
# 184031  208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# 173831      239.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 183819      325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 85525        276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 41872        717.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# ...                                                   ...
# 119879       350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 103694  320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 131932  420.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 146867      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 121958                    3.0L V6 24V PDI DOHC Twin Turbo
#
#                              transmission      ext_col int_col  ...  \
# 184031     Transmission w/Dual Shift Mode         Gray   Black  ...
# 173831                                A/T       Silver    Gray  ...
# 183819                       10-Speed A/T         Gray    Gray  ...
# 85525                         6-Speed M/T        Black   Black  ...
# 41872                         6-Speed A/T          Red   Black  ...
# ...                                   ...          ...     ...  ...
# 119879                        6-Speed M/T          Red   Beige  ...
# 103694                        7-Speed A/T        Black   Black  ...
# 131932                        8-Speed A/T        Black   Black  ...
# 146867                        7-Speed A/T        Black   Black  ...
# 121958  8-Speed Automatic with Auto-Shift  Matte White   Black  ...
#
#        additional_features_Dual Shift Mode  additional_features_Fixed Gear  \
# 184031                                True                           False
# 173831                               False                           False
# 183819                               False                           False
# 85525                                False                           False
# 41872                                False                           False
# ...                                    ...                             ...
# 119879                               False                           False
# 103694                               False                           False
# 131932                               False                           False
# 146867                               False                           False
# 121958                               False                           False
#
#         additional_features_None  additional_features_Overdrive  ext_col_R  \
# 184031                     False                          False        128
# 173831                      True                          False        192
# 183819                      True                          False        128
# 85525                       True                          False          0
# 41872                       True                          False        255
# ...                          ...                            ...        ...
# 119879                      True                          False        255
# 103694                      True                          False          0
# 131932                      True                          False          0
# 146867                      True                          False          0
# 121958                     False                          False          0
#
#         ext_col_G  ext_col_B  int_col_R  int_col_G  int_col_B
# 184031        128        128          0          0          0
# 173831        192        192        128        128        128
# 183819        128        128        128        128        128
# 85525           0          0          0          0          0
# 41872           0          0          0          0          0
# ...           ...        ...        ...        ...        ...
# 119879          0          0        245        245        220
# 103694          0          0          0          0          0
# 131932          0          0          0          0          0
# 146867          0          0          0          0          0
# 121958          0          0          0          0          0
#
# [150826 rows x 50 columns]

# %%
df_val_data
# Out:
#             id   brand                   model  model_year  milage fuel_type  \
# 111355  111355  Nissan               Murano SV        2022   23677  Gasoline
# 182258  182258    Ford      Thunderbird Deluxe        2004   50000  Gasoline
# 14147    14147   Buick          Enclave Avenir        2019  109646  Gasoline
# 79313    79313     BMW                   340 i        2016  102000  Gasoline
# 101160  101160  Toyota           Highlander SE        2020   75151  Gasoline
# ...        ...     ...                     ...         ...     ...       ...
# 71604    71604    Ford     Expedition Platinum        2021   71536  Gasoline
# 137137  137137    Land        Rover Defender S        2023    2121    Hybrid
# 70567    70567   Acura           TL Technology        2013   72639  Gasoline
# 94567    94567   Scion  tC Anniversary Edition        2013  115000  Gasoline
# 105952  105952    Ford              Mustang GT        2001    6400  Gasoline
#
#                                                    engine        transmission  \
# 111355                              3.5L V6 24V MPFI DOHC       Automatic CVT
# 182258       280.0HP 3.9L 8 Cylinder Engine Gasoline Fuel                 A/T
# 14147                                3.6L V6 24V GDI DOHC   9-Speed Automatic
# 79313   320.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 101160      295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         8-Speed A/T
# ...                                                   ...                 ...
# 71604                     3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 137137  296.0HP 2.0L 4 Cylinder Engine Gasoline/Mild E...         8-Speed A/T
# 70567       280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 94567        179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel                 A/T
# 105952       300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel         6-Speed M/T
#
#                          ext_col   int_col  ...  \
# 111355  Sunset Drift Chromaflair  Graphite  ...
# 182258                      Gold     Beige  ...
# 14147                  Dark Moss  Chestnut  ...
# 79313                      White     Black  ...
# 101160                      Gray     Black  ...
# ...                          ...       ...  ...
# 71604                       Gray   Ceramic  ...
# 137137                     White     Black  ...
# 70567                        Red      Gray  ...
# 94567                      White     Beige  ...
# 105952                      Gray     Black  ...
#
#        additional_features_Dual Shift Mode  additional_features_Fixed Gear  \
# 111355                               False                           False
# 182258                               False                           False
# 14147                                False                           False
# 79313                                False                           False
# 101160                               False                           False
# ...                                    ...                             ...
# 71604                                False                           False
# 137137                               False                           False
# 70567                                False                           False
# 94567                                False                           False
# 105952                               False                           False
#
#         additional_features_None  additional_features_Overdrive  ext_col_R  \
# 111355                      True                          False          0
# 182258                      True                          False        255
# 14147                       True                          False          0
# 79313                       True                          False        255
# 101160                      True                          False        128
# ...                          ...                            ...        ...
# 71604                       True                          False        128
# 137137                      True                          False        255
# 70567                       True                          False        255
# 94567                       True                          False        255
# 105952                      True                          False        128
#
#         ext_col_G  ext_col_B  int_col_R  int_col_G  int_col_B
# 111355          0          0          0          0          0
# 182258        215          0        245        245        220
# 14147           0          0          0          0          0
# 79313         255        255          0          0          0
# 101160        128        128          0          0          0
# ...           ...        ...        ...        ...        ...
# 71604         128        128          0          0          0
# 137137        255        255          0          0          0
# 70567           0          0        128        128        128
# 94567         255        255        245        245        220
# 105952        128        128          0          0          0
#
# [37707 rows x 50 columns]

# %%
test_data
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# 0       Gasoline       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 1         Hybrid  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       Gasoline                    3.5L V6 24V PDI DOHC Twin Turbo
# 3       Gasoline                                     2.0 Liter TFSI
# 4       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...          ...                                                ...
# 125685  Gasoline      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125686  Gasoline                                    3.0 Liter Turbo
# 125687  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125688  Gasoline      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 125689  Gasoline       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#               transmission          ext_col int_col  ...  \
# 0              6-Speed A/T            White   Beige  ...
# 1              8-Speed A/T           Silver   Black  ...
# 2       10-Speed Automatic            White   Ebony  ...
# 3                Automatic  Silician Yellow   Black  ...
# 4                      A/T             Gray   Black  ...
# ...                    ...              ...     ...  ...
# 125685         7-Speed A/T            Black   Black  ...
# 125686           Automatic            White   Black  ...
# 125687                 A/T            Black   Black  ...
# 125688                 A/T            Black   Black  ...
# 125689                 A/T           Silver   Black  ...
#
#        additional_features_Dual Shift Mode  additional_features_Fixed Gear  \
# 0                                    False                           False
# 1                                    False                           False
# 2                                    False                           False
# 3                                    False                           False
# 4                                    False                           False
# ...                                    ...                             ...
# 125685                               False                           False
# 125686                               False                           False
# 125687                               False                           False
# 125688                               False                           False
# 125689                               False                           False
#
#         additional_features_None  additional_features_Overdrive  ext_col_R  \
# 0                           True                          False        255
# 1                           True                          False        192
# 2                           True                          False        255
# 3                           True                          False          0
# 4                           True                          False        128
# ...                          ...                            ...        ...
# 125685                      True                          False          0
# 125686                      True                          False        255
# 125687                      True                          False          0
# 125688                      True                          False          0
# 125689                      True                          False        192
#
#         ext_col_G  ext_col_B  int_col_R  int_col_G  int_col_B
# 0             255        255        245        245        220
# 1             192        192          0          0          0
# 2             255        255          0          0          0
# 3               0          0          0          0          0
# 4             128        128          0          0          0
# ...           ...        ...        ...        ...        ...
# 125685          0          0          0          0          0
# 125686        255        255          0          0          0
# 125687          0          0          0          0          0
# 125688          0          0          0          0          0
# 125689        192        192          0          0          0
#
# [125690 rows x 48 columns]
